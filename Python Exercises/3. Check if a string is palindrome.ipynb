# %% [markdown]
# ## Check if a string is palindrome
#
# Given a string, write a python function to check if it is
# palindrome or not.
#
# A string is said to be palindrome if the reverse
# of the string is the same as string. For example, “malayalam” is a
# palindrome, but “music” is not a palindrome.

# %%
def ispalindrome(s):
    return s == s[::-1]

s = 'malayalam'
ans = ispalindrome(s)

if ans:
    print ("Is palindrome!!")
else:
    print ('Is not palindrome!')
# Out:
# Is palindrome!!

# %%
# using iterative method

def ispalindrome(s):
    
    for i in range(0,int(len(s)/2)):
        if s[i] != s[len(str)-i-1]:
            return False
    return True

s = 'malayalam'
ans = ispalindrome(s)

if ans:
    print ("Is palindrome!!")
else:
    print ('Is not palindrome!')
# Out:
# Is palindrome!!

# %%
# Check String is Palindrome or Not Using the inbuilt function to reverse a string

# function to check string is
# palindrome or not
def isPalindrome(s):
	rev = ''.join(reversed(s))
	if (s == rev):
		return True
	return False

# main function
s = "malayalam"
ans = isPalindrome(s)

if (ans):
	print("Yes")
else:
	print("No")
# Out:
# Yes

# %%
x = "juice"
 
w = ""
for i in x:
    w = i + w
 
if (x == w):
    print("Yes, it is palindrome")
else:
    print("No, its not palindrome")
# Out:
# No, its nto palindrome

# %%
st = 'malayalam'
j = -1
flag = 0
for i in st:
    if i != st[j]:
        flag = 1
        break
    j = j - 1
if flag == 1:
    print("NO")
else:
    print("Yes")
# Out:
# Yes

# %%
# Using recursion 

def isPalindrome(s):
 
    # to change it the string is similar case
    s = s.lower()
    # length of s
    l = len(s)
 
    # if length is less than 2
    if l < 2:
        return True
 
    # If s[0] and s[l-1] are equal
    elif s[0] == s[l - 1]:
 
        # Call is palindrome form substring(1,l-1)
        return isPalindrome(s[1: l - 1])
 
    else:
        return False
 
# Driver Code
s = "MalaYaLam"
ans = isPalindrome(s)
 
if ans:
    print("Yes")
 
else:
    print("No")

# %%
str = "malayalam"
stlen = len(str)
revstr = []

for i in range (stlen):
    for j in range(stlen-1, 0, -1):
        revstr[i]= str[j]
    

if str == revstr:
    print ("The string is Palindrome")
else:
    print ("No! the string is NOT a palindrome")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[24], line 7
#       5 for i in range (stlen):
#       6     for j in range(stlen-1, 0, -1):
# ----> 7         revstr[i]= str[j]
#      10 if str == revstr:
#      11     print ("The string is Palindrome")
#
# IndexError: list assignment index out of range

# %% [markdown]
# Referecnes:
#
#     https://www.geeksforgeeks.org/python-program-to-check-whether-the-string-is-symmetrical-or-palindrome/

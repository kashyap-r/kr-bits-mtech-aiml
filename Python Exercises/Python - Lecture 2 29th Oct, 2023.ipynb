# %%
# List

# %%
# Tuple

# %%
# Set

# %%
# Set functions like intersection, union 

set1 = {1, 2, 3, 4, 5}
set2 = {1, 2, 3}
set3 = {3, 5}

set1.intersection(set2)
# Out:
# {1, 2, 3}

# %%
# heterogeneous set 
set4 = {1, 2, 'kashyap', 4, 5}

# %%
set1 - set2
# Out:
# {4, 5}

# %%
# Difference between tuple and a set 

# difference between string and a list

# %% [markdown]
# ## Dictionary

# %%
# Floor Division

# %%
# Bitwise Operators

# %%
# import libraries 
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt

# %%
# Assignment 1 Set 11 Dataset
# import dataset 
data_file = 'Assignment_1_Set_11_Dataset.csv'
# hdset = pd.read_csv(data_file, index_col = 0)
# hdf = pd.read_csv(data_file, index_col = 0).T
hdset = pd.read_csv(data_file)

# %% [markdown]
# # Heart Disease Prediction
#
# Analyze each feature w.r.t
#     - find the meaning of each feature
#     - find how the values of feature vary
#     - what does it mean when a feature values have extreme values
#     - what is the normal acceptable range of values for each of the feature
#
# Analyze two or more features w.r.t. each other..
#
# ### List of Features
#     age = age of the person
#     sex= gender
#     cp = chest pain types
#     trestbps = heart beat per sec at rest
#     chol = cholestrol
#     fbs= fasting blood sugar
#     restecg= resting electrocardiographic results (values 0,1,2)
#     thalach= maximum heart rate achieved
#     exang= exercise induced angina
#     oldpeak= ST depression induced by exercise relative to rest
#     slope= the slope of the peak exercise ST segment
#     ca= number of major vessels (0-3) colored by flourosopy
#     thal=  0 = normal; 1 = fixed defect; 2 = reversable defect
#     target=
#
# ### The features following are used for the prediction of heart disease presence:
#
# ### age: age of the person in years
#      datatype -> number
#      range -> 1 - 100
#
# ### sex: displays the gender of the individual using the following format
#     0 = Female
#     1 = Male
#
# ### cp: Chest pain types
#         0 = Typical angina
#         1 = Atypical angina
#         2 = Non-angina pain
#         3 = Asymptomatic
#
#     0 = Typical angina
#         Angina is a type of chest pain caused by reduced blood flow to the heart. Angina is a symptom of
#         coronary artery disease. Angina also is called angina pectoris. Angina is often described as squeezing, pressure, heaviness,
#         tightness or pain in the chest.
#         What are the three criteria for typical angina?
#             Meets three of the following characteristics:
#             Substernal chest discomfort of characteristic quality and duration.
#             Provoked by exertion or emotional stress.
#             Relieved by rest and/or nitroglycerine.
#
#     1 = Atypical angina
#         Atypical chest pain is a type of chest pain that only has some of the features of typical chest pain. It may also include chest pain that: Lasts for a few seconds, then quickly subsides. Worsens when your body is in certain positions. Feels like a sharp or stabbing pain.
#         'Atypical angina' is defined as chest pain not fully satisfying criteria for 'typical' angina but somehow consistent with
#         cardiac ischaemic cause.
#
#     2 = Non-angina pain
#         In these cases, nonanginal pain may feel similar to a heart attack because the heart and the esophagus are next to each other,
#         and the same nerves travel through them. Other possible esophageal and gastrointestinal causes of nonanginal pain may include:
#         esophageal motility disorders.
#         Both anxiety and panic attack can cause symptoms very similar to angina. These attacks—which can occur out of the blue or in
#         response to a stressful event—include chest pain along with shortness of breath, palpitations, and dizziness.
#
#     3 = Asymptomatic
#         Silent myocardial ischemia is a condition of reduced oxygen-rich blood flow to the heart that occurs in the absence of chest
#         discomfort or other symptoms of angina, e.g., dyspnea, nausea, diaphoresis, etc.
#
#     Analysis
#         * Different age groups with chest pain & Distribution of chest pain types with age groups
#         * Distribution of chest pain types with by age group and gender
#
# ### trestbps: Resting blood pressure (mmHg) - displays the resting blood pressure value of an individual in mmHg (unit)
#     High blood pressure = 140 mmHg or above
#
#     Description
#
#     Analysis
#         How does trestbps vary with different types of chestpaintypes
#         Does age have an influence on the resting bp
#         Does gender have an influence on the resting bp
#
# ### chol: Serum cholestoral (mg/dL)
#
#     Description
#         Certain elements in the blood, including low-density lipoprotein (LDL), high-density lipoprotein (HDL) and triglycerides
#         Calculation = HDL + LDL + 0.2 * triglycerides
#         Higher than 200 mg/dL is concerned
#
#     Analysis
#         influence on chestpain types
#         influence on rest_bp
#         how chol varies by age
#         how chol varies by gender
#         how chol varies by age and sex
#
#
# ### fbs: Fasting blood sugar (> 120 mg/dL)
#
#     Description
#         compares the fasting blood sugar value of an individual with 120mg/dl.
#
# If fasting blood sugar > 120mg/dl then :11 (true)
# else : 0 (false
#           Higher than 126 mg/dL points to diabetes
#
#     Analysis
#         variance of fbs by age
#         does gender makes a difference in fbs
#         In what way fbs values are related to chest pain type
#
#         just for academic interest fbs vs restbp
#
# ### restecg: Resting electrocardiographic results
#     0 = Normal
#     1 = Abnormal ST-T wave
#     2 = Showing probable or definite left ventricular hypertrophy
#
#     Description:
#         It's important to treat the causes of LVH early because it can lead to severe problems such as heart failure, sudden cardiac arrest and ischemic stroke
#
#     Analysis
#         * age / sex versus rest ecg
#         * when rest ecg = 1 what is chol and fbs
#         * is there any chest pain when restecg = 1
#
#         * when rest ecg = 2 what is chol and fbs
#         * is there any chest pain when restecg = 2
#
# ### thalach: Maximum heart rate achieved (bpm)
#     The person’s maximum heart rate achieved.
#
#     Analysis
#         relation between rest bp and thalach
#         relation with thalach and restecg
#         relation with chol and cp_type
#         age
#
# ### exang: Exercise induced angina
#     Angine is pain in the chest that comes on with exercise, stress, or other things that make the heart work harder.
#
#     0 = Negative
#     1 = Positive
#
#     Analysis
#         relation with restecg
#         relation with thalach, restbp and cptype
#
# ### oldpeak: ST depression induced by exercise relative to rest
#     Description
#         ST depression occurs when the J point is displaced below baseline. Just like ST elevation, not all ST depression represents myocardial ischemia or an emergent condition. There are multiple conditions associated with ST depression. Some of these include hypokalemia, cardiac ischemia, and medications such as digitalis.
#         ST depression can be either upsloping, downsloping, or horizontal (see diagram below). Horizontal or downsloping ST depression ≥ 0.5 mm at the J-point in ≥ 2 contiguous leads indicates myocardial ischaemia (according to the 2007 Task Force Criteria). ST depression ≥ 1 mm is more specific and conveys a worse prognosis.
#
#         Patients with angina and coronary artery disease (CAD) have many episodes of transient ST-segment depression during ordinary daily life, and these are often asymptomatic.
#
#     Check this out
#         ST segment depression in the absence of demonstrable myocardial ischemia during exercise is a common finding, with a higher prevalence in women than in young or middle-aged men
#
#
# ### slope: The slope of the peak exercise ST segment
#     0 = Upsloping
#     1 = Horizontal / Flat
#     2 = Downsloping
#
#
# ### ca: Number of major vessels (0-3) colored by fluoroscopy
#     The colored blood vessels are passing through
#     There is a clot if the blood vessel is not colore
#
#     num_vessels: Number of major vessels colored by fluoroscopy
#
# Categorical variable with the following values    :
# 0: No    ne
# 1:     One
# 2:     Two
# 3: Threed
#
# ### thal: Thallium scintigraphy
#     3 = Normal
#     6 = Fixed defect
#     7 = Reversable defect
#
#     The thal value is 3 = normal; 6 = fixed defect; 7 = reversable defect
#
# ### target: Heart Disease
#     0 / absence  = Benign
#     1 =  or if any other value Malignant

# %% [markdown]
# Why these parameters:
# In the actual dataset, we had 76 features but for our study, we chose only the above 14 because :
#
# Age:
#     Age is the most important risk factor in developing cardiovascular or heart diseases, with approximately a tripling of risk with
#     each decade of life. Coronary fatty streaks can begin to form in adolescence. It is estimated that 82 percent of people who die
#     of coronary heart disease are 65 and older. Simultaneously, the risk of stroke doubles every decade after age 55.
#
# Sex:
#     Men are at greater risk of heart disease than pre-menopausal women. Once past menopause, it has been argued that a woman’s risk
#     is similar to a man’s although more recent data from the WHO and UN disputes this. If a female has diabetes, she is more likely
#     to develop heart disease than a male with diabetes.
#
# Angina (Chest Pain):
#     Angina is chest pain or discomfort caused when your heart muscle doesn’t get enough oxygen-rich blood. It may feel like pressure
#     or squeezing in your chest. The discomfort also can occur in your shoulders, arms, neck, jaw, or back. Angina pain may even feel
#     like indigestion.
#
# Resting Blood Pressure:
#     Over time, high blood pressure can damage arteries that feed your heart. High blood pressure that occurs with other conditions,
#     such as obesity, high cholesterol or diabetes, increases your risk even more.
#
# Serum Cholesterol:
#     A high level of low-density lipoprotein (LDL) cholesterol (the “bad” cholesterol) is most likely to narrow arteries. A high level
#     of triglycerides, a type of blood fat related to your diet, also ups your risk of a heart attack. However, a high level of high-
#     density lipoprotein (HDL) cholesterol (the “good” cholesterol) lowers your risk of a heart attack.
#
# Fasting Blood Sugar:
#     Not producing enough of a hormone secreted by your pancreas (insulin) or not responding to insulin properly causes your body’s
#     blood sugar levels to rise, increasing your risk of a heart attack.
#
# Resting ECG:
#     For people at low risk of cardiovascular disease, the USPSTF concludes with moderate certainty that the potential harms of screening
#     with resting or exercise ECG equal or exceed the potential benefits. For people at intermediate to high risk, current evidence is
#     insufficient to assess the balance of benefits and harms of screening.
#
# Max heart rate achieved:
#     The increase in cardiovascular risk, associated with the acceleration of heart rate, was comparable to the increase in risk observed
#     with high blood pressure. It has been shown that an increase in heart rate by 10 beats per minute was associated with an increase in
#     the risk of cardiac death by at least 20%, and this increase in the risk is similar to the one observed with an increase in systolic
#     blood pressure by 10 mm Hg.
#
# Exercise induced angina:
#     The pain or discomfort associated with angina usually feels tight, gripping or squeezing, and can vary from mild to severe. Angina is
#     usually felt in the center of your chest but may spread to either or both of your shoulders, or your back, neck, jaw or arm. It can
#     even be felt in your hands. o Types of Angina a. Stable Angina / Angina Pectoris b. Unstable Angina c. Variant (Prinzmetal) Angina d.
#     Microvascular Angina.
# Peak exercise ST segment:
#     A treadmill ECG stress test is considered abnormal when there is a horizontal or down-sloping ST-segment depression ≥ 1 mm at 60–80 ms
#     after the J point. Exercise ECGs with up-sloping ST-segment depressions are typically reported as an ‘equivocal’ test. In general, the
#     occurrence of horizontal or down-sloping ST-segment depression at a lower workload (calculated in METs) or heart rate indicates a worse
#     prognosis and higher likelihood of multi-vessel disease. The duration of ST-segment depression is also important, as prolonged recovery
#     after peak stress is consistent with a positive treadmill ECG stress test. Another finding that is highly indicative of significant CAD
#     is the occurrence of ST-segment elevation > 1 mm (often suggesting transmural ischemia); these patients are frequently referred urgently
#     for coronary angiography.

# %%
# 1. Identify the type of variables 
# 2. Then rename the variable
# age -> age
# sex -> sex
# cp -> chestpain_type
# trestbps -> resting_bp
# chol -> cholesterol_lvl
# fbs -> fasting_bs
# restecg -> resting_ecg
# thalach -> max_heart_rate
# exang -> exercise_induced_angina
# oldpeak -> st_depression
# slope -> ST_slope
# ca -> Num_major_vessels
# thal -> Thalium_tst
# target -> heart_condition

hdset = hdset.rename(columns={'age':'age', 
                      'sex':'gender',
                      'cp':'cp_type',
                      'trestbps':'rest_bp',
                      'chol':'chol_lvl',
                      'fbs':'fast_bs',
                      'restecg':'rest_ecg',
                      'thalach':'max_heart_rate',
                      'exang':'ex_ind_angina',
                      'oldpeak':'st_depression',
                      'slope': 'st_slope',
                      'ca':'num_maj_vessel',
                      'thal':'thalium_tst',
                      'target':'heart_condition'                   
                     })
# hds.columns

# %%
hdset.columns
# Out:
# Index(['age', 'gender', 'cp_type', 'rest_bp', 'chol_lvl', 'fast_bs',
#        'rest_ecg', 'max_heart_rate', 'ex_ind_angina', 'st_depression',
#        'st_slope', 'num_maj_vessel', 'thalium_tst', 'heart_condition'],
#       dtype='object')

# %%
### age: age of the person in years
"""
     datatype -> numeric
     range -> 1 - 100
"""
print (hdset['age'].describe())
print (hdset['age'].unique())
print ('distribution of age')
# sns.displot(hdset, x="age")
# fig = px.histogram(hdset, x="age")
# fig = px.histogram(hdset, x="age", nbins=100)
fig = px.histogram(hdset, x="age")
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# count    1025.000000
# mean       54.434146
# std         9.072290
# min        29.000000
# 25%        48.000000
# 50%        56.000000
# 75%        61.000000
# max        77.000000
# Name: age, dtype: float64
# [52 53 70 61 62 58 55 46 54 71 43 34 51 50 60 67 45 63 42 44 56 57 59 64
#  65 41 66 38 49 48 29 37 47 68 76 40 39 77 69 35 74]
# distribution of age

# %%
plt.figure(figsize=(18,12))
plt.subplot(221)
plt.title("Distribution of Gender")
hdset["gender"].value_counts().plot.pie(autopct = "%1.0f%%",colors = sns.color_palette("ocean_r",5),startangle = 90,labels=["Male","Female"],
wedgeprops={"linewidth":2,"edgecolor":"k"},explode=[.1,.1], shadow =True)
plt.subplot(222)
# ax = hdset.plot.hist(column=["age"], by="gender", figsize=(10, 8))
plt.show()

# %%
# Age distribution vs the target variable

# %%
"""
Analysis 
        * Different age groups with chest pain & Distribution of chest pain types with age groups 
        * Distribution of chest pain types with by age group and gender 

"""
print (f"The distinct values of the variables... :{hdset['cp_type'].unique()}")
print (hdset['cp_type'].describe())
# Out:
# The distinct values of the variables... :[0 1 2 3]
# count    1025.000000
# mean        0.942439
# std         1.029641
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         2.000000
# max         3.000000
# Name: cp_type, dtype: float64

# %% [markdown]
# #### Gender Distribution vs the target variable

# %%
hdset['gender'].groupby(hdset['heart_condition']).value_counts(normalize=True).rename('ratio').reset_index().pipe((sns.barplot, 'data'), x='gender', y='ratio', hue='heart_condition', palette='Dark2');
plt.title('Distribution of occurance Heart Diesease by Gender')
plt.xlabel('Gender (0 = Female, 1 = Male)')
plt.show()

# female_malignant vs. Malignant
f_dieseased = hdset[hdset['gender']==0]['heart_condition'].sum()/hdset[hdset['heart_condition']==1]['heart_condition'].count()
# male_malignant vs. Malignant
m_dieseased = hdset[hdset['gender']==1]['heart_condition'].sum()/hdset[hdset['heart_condition']==1]['heart_condition'].count()

print('Distribution of occurance Heart Diesease by Gender:')
print(f'Female: {f_dieseased:.2%}')
print(f'Male: {m_dieseased:.2%}')
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning:
#
# is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
# Distribution of occurance Heart Diesease by Gender:
# Female: 42.97%
# Male: 57.03%

# %%
# hdset['thalach'].unique().tolist()
hdset['oldpeak'].describe()
# Out:
# count    1025.000000
# mean        1.071512
# std         1.175053
# min         0.000000
# 25%         0.000000
# 50%         0.800000
# 75%         1.800000
# max         6.200000
# Name: oldpeak, dtype: float64

# %%
hdset['slope'].unique()
# Out:
# array([2, 0, 1], dtype=int64)

# %%
# hdset.describe

# %% [markdown]
# The features following are used for the prediction of heart disease presence:nant

# %%
# Rename the columns

# %%
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
hdset ['age']
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %% [markdown]
# sex:
#
#     0 = Female
#     1 = Male

# %%
hdset['sex']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 1020    1
# 1021    1
# 1022    1
# 1023    0
# 1024    1
# Name: sex, Length: 1025, dtype: int64

# %%
hdset['cp'].unique()
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %% [markdown]
# trestbps: Resting blood pressure (mmHg)
#
# High blood pressure = 140 mmHg or above

# %%
print (f"THe minimum and maximum values of trestbps")
print (hdset['trestbps'].min())
print (hdset['trestbps'].max())
# Out:
# THe minimum and maximum values of trestbps
# 94
# 200

# %% [markdown]
# chol: Serum cholestoral (mg/dL)
# Certain elements in the blood, including low-density lipoprotein (LDL), high-density lipoprotein (HDL) and triglycerides
# Calculation = HDL + LDL + 0.2 * triglycerides
# Higher than 200 mg/dL is concerned

# %%
fbs: Fasting blood sugar (> 120 mg/dL)
0 = False
1 = True
Higher than 126 mg/dL points to diabetes

# %%
restecg: Resting electrocardiographic results
0 = Normal
1 = Abnormal ST-T wave
2 = Showing probable or definite left ventricular hypertrophy

# %%
thalach: Maximum heart rate achieved (bpm)

# %%
exang: Exercise induced angina
0 = Negative
1 = Positive

# %%
oldpeak: ST depression induced by exercise relative to rest

# %%
slope: The slope of the peak exercise ST segment
0 = Upsloping
1 = Horizontal
2 = Downsloping

# %%
ca: Number of major vessels (0-3) colored by fluoroscopy
The colored blood vessels are passing through
There is a clot if the blood vessel is not colored

# %%
thal: Thallium scintigraphy
3 = Normal
6 = Fixed defect
7 = Reversable defect

# %%
target: Heart Disease
0 = Benign
1 = Malignant

# %%
# To-Do: Check out Missing Values
hdf.head(5)
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 52     1   0       125   212    0        1      168      0      1.0      2
# 53     1   0       140   203    1        0      155      1      3.1      0
# 70     1   0       145   174    0        1      125      1      2.6      0
# 61     1   0       148   203    0        1      161      0      0.0      2
# 62     0   0       138   294    1        1      106      0      1.9      1
#
#      ca  thal  target
# age
# 52    2     3       0
# 53    0     3       0
# 70    0     3       0
# 61    1     3       0
# 62    3     2       0

# %%
hdfs = hdf.describe()
hdfs
# Out:
#                sex           cp     trestbps        chol          fbs  \
# count  1025.000000  1025.000000  1025.000000  1025.00000  1025.000000
# mean      0.695610     0.942439   131.611707   246.00000     0.149268
# std       0.460373     1.029641    17.516718    51.59251     0.356527
# min       0.000000     0.000000    94.000000   126.00000     0.000000
# 25%       0.000000     0.000000   120.000000   211.00000     0.000000
# 50%       1.000000     1.000000   130.000000   240.00000     0.000000
# 75%       1.000000     2.000000   140.000000   275.00000     0.000000
# max       1.000000     3.000000   200.000000   564.00000     1.000000
#
#            restecg      thalach        exang      oldpeak        slope  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.529756   149.114146     0.336585     1.071512     1.385366
# std       0.527878    23.005724     0.472772     1.175053     0.617755
# ...

# %%
hdf.head()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 52     1   0       125   212    0        1      168      0      1.0      2
# 53     1   0       140   203    1        0      155      1      3.1      0
# 70     1   0       145   174    0        1      125      1      2.6      0
# 61     1   0       148   203    0        1      161      0      0.0      2
# 62     0   0       138   294    1        1      106      0      1.9      1
#
#      ca  thal  target
# age
# 52    2     3       0
# 53    0     3       0
# 70    0     3       0
# 61    1     3       0
# 62    3     2       0

# %%
hdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1025 entries, 52 to 54
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   sex       1025 non-null   int64
#  1   cp        1025 non-null   int64
#  2   trestbps  1025 non-null   int64
#  3   chol      1025 non-null   int64
#  4   fbs       1025 non-null   int64
#  5   restecg   1025 non-null   int64
#  6   thalach   1025 non-null   int64
#  7   exang     1025 non-null   int64
#  8   oldpeak   1025 non-null   float64
#  9   slope     1025 non-null   int64
#  10  ca        1025 non-null   int64
#  11  thal      1025 non-null   int64
#  12  target    1025 non-null   int64
# dtypes: float64(1), int64(12)
# memory usage: 112.1 KB

# %%
hdf.columns
# Out:
# Index(['sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang',
#        'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
import matplotlib as plt

# %%
hdf.groupby('sex').count()
# Out:
#       cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope   ca  \
# sex
# 0    312       312   312  312      312      312    312      312    312  312
# 1    713       713   713  713      713      713    713      713    713  713
#
#      thal  target
# sex
# 0     312     312
# 1     713     713

# %%
hdf.head()
# Out:
#      sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# age
# 52     1   0       125   212    0        1      168      0      1.0      2
# 53     1   0       140   203    1        0      155      1      3.1      0
# 70     1   0       145   174    0        1      125      1      2.6      0
# 61     1   0       148   203    0        1      161      0      0.0      2
# 62     0   0       138   294    1        1      106      0      1.9      1
#
#      ca  thal  target
# age
# 52    2     3       0
# 53    0     3       0
# 70    0     3       0
# 61    1     3       0
# 62    3     2       0

# %%
# %matplotlib inline
# Out:
# <Axes: xlabel='age'>

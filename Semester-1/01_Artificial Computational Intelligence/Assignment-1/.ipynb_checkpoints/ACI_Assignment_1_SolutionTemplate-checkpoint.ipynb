# %% [markdown]
# # Artificial and Computational Intelligence Assignment 1

# %% [markdown]
# ## Problem solving by Uninformed & Informed Search

# %% [markdown]
# List only the BITS (Name) of active contributors in this assignment:
# 1. KASHYAP RAJPUROHIT (BITS ID: 2023ab05027)
# 2. VIBHAV RAMAN (BITS ID: 2023aa05805)
# 3. ____________________
# 4. ___________________
# 5. ___________________

# %% [markdown]
# Things to follow
# 1.	Use appropriate data structures to represent the graph and the path using python libraries
# 2.	Provide proper documentation
# 3.	Find the path and print it

# %% [markdown]
# Coding begins here

# %% [markdown]
# ### 1.	Define the environment in the following block

# %% [markdown]
# The environment in this case is the map of the city which would comprise of the households which have to be visited. The roads connecting the households with the distance and the cost of travel between the households.
#
# Performance: Minimize total distance which the delivery robot has to travel and cover all the households
# Environment: City map, Roads, households
# Actuators: Navigation controls, Maps
# Sensors: GPS to check location and route, Proximity sensors
#
#
# Problem Solving Agents
# The Problem solving agents would have the following characteristics
# Initial State – Starts from node A
# Possible Action Operation: Traverse through the connected node with the lowest cost
# Successor Function: Closed List = Nodes visited
# 		        Open List = Nodes yet to visit
# Goal Test   = From the initial node reach the target covering all the nodes.
# Path Cost = Cumulative distance covered in the path
# Heuristic = The average of the total distance cost across all these paths is the heuristic value h(n).
#
# f(n) = h(n)+g(n)

# %% [markdown]
# Design the agent as PSA Agent(Problem Solving Agent)
# Clear Initial data structures to define the graph and variable declarations is expected
# IMPORTATANT: Write distinct code block as below

# %%
#Code Block : Set Initial State (Must handle dynamic inputs)

class Graph:
     
    def __init__(self, len_v):                
        self.num_nodes = len_v
        self.nodes = ["A", "B", "C", "D", "E", "F", "G", "H"]
        """Initializes the graph with an adjacency list filled with -1's """
        self.edges = np.array([[-1 for i in range(len_v)] for j in range(len_v)])
    
    def generate_edges(self, size):        
        grid = np.array([[0, 15, 10, 17, 0, 0, 5, 0],
               [15, 0, 0, 12, 0, 0, 0, 0],
               [10, 0, 0, 0, 0, 0, 7, 0],
               [17, 12, 0, 0, 0, 0, 0, 4],
               [0, 0, 0, 2, 0, 0, 0, 0],
               [0, 0, 0, 10, 0, 0, 0, 11],
               [5, 0, 7, 0, 0, 0, 0, 25],
               [0, 0, 0, 4, 0, 0, 25, 0]            
               ])
    
        for i in range(num_nodes):
            for j in range(num_nodes):
                self.edges[i][j] = grid [i][j]

# %%
#Code Block : Set the matrix for transition & cost (as relevant for the given problem)

    """Define the heuristic function as the average distance from an arbitrary node to the goal node"""
    def heuristic(self, node, goal):
        """
        Parameters: 
            node - start node 
            goal - goal node         
        Returns: avgDistance - Return the average distance to the goal node        
        Description: This method does the below steps in order 
            1. Extract the indices of the start node and goal node
            2. Then, extracts the distances from the start node
            3. Then, gets the distances from the goal node to rest of all  nodes
            4. Calculate the average distance by adding the node and goal distances and dividing by 2
        """
        
        nodeIndex = self.nodes.index(node)
        goalIndex = self.nodes.index(goal)
        nodeDist = self.edges[nodeIndex]
        goalDist = self.edges[goalIndex]
        avgDistance = (nodeDist + goalDist) / 2
        
        return avgDistance[goalIndex]

# %%
#Code Block : Write function to design the Transition Model/Successor function. Ideally this would be called while search algorithms are implemented

    """ The IDA* path-finding algorithm           """
    def ida_star(self, start, goal):
        """ 
        Parameters:
            graph: Graph-class object, which represents a graph.
            start: The starting node for the algorithm.
            goal: The goal node for the algorithm.
         Returns:
            integer: Returns the distance from starting node to the goal node.
            
         Description: Invokes the search method, that performs the depth-first search with
         heuristic values to choose optimal paths.
         
        """       
        # Initialize limit as the heuristic value of the start node
        limit = self.heuristic(start, goal)
        # Initialize the path with the start node
        path = [start]
        
        # Loop until a solution is found or no more nodes to visit
        while True:                        
            # Call the recursive search function 
            result = self.rec_ids_heuristics(path, 0, limit, goal)
            # If the result is negative, then solution found
            if result < 0:
                # Print the path and the cost
                print("Solution found:", path, -result)                
                return path, -result
            # If the result is infinity, no solution is possible
            elif result == float("inf"):                
                print("No solution possible")                
                return None            
            else:
                limit = result

# %%
#Code block : Write fucntion to handle goal test (Must handle dynamic inputs). Ideally this would be called while search algorithms are implemented

# %% [raw]
# 2. Definition of Algorithm 1 (IDA*)

# %%
#Code Block : Function for algorithm 1 implementation

def rec_ids_heuristics(self, path, cost, limit, goal):
        """
        Parameters: 
            path - path to be traversed
            cost - cost of the path
            limit - depth of traversal
            goal - goal node
        
        Returns: return the minium value        
        Description:        
        """
        # current node from the path
        node = path[-1]
        # Calculate the f value as the cost plus the heuristic value
        # f(n) = c(n) + h(n)
        f = cost + self.heuristic(node, goal)        
        
        print("Visiting node:", node, "with f value:", f)        
        if f > limit:
            return f
        
        # If the current node is the goal node, return the cost
        if node == goal:
            return -cost
                
        min_value = float("inf")
        
        for neighbor in self.nodes:
            # Get the distance to the neighbor
            distance = self.edges[self.nodes.index(node), self.nodes.index(neighbor)]            
            if distance != 0 and neighbor not in path:            
                path.append(neighbor)
                # Call the search function recursively with the updated path, cost, and threshold
                result = self.rec_ids_heuristics(path, cost + distance, limit, goal)
                # If the result is negative, solution is found
                if result < 0:                    
                    return result                
                if result < min_value:
                    min_value = result                
                path.pop()        
        return min_value

# %% [markdown]
# ### 3.	Definition of Algorithm 2 (Genetic Algorithm)

# %%
#Code Block : Function for algorithm 2 implementation

import numpy as np
import random


nodes = ["A", "B", "C", "D", "E", "F", "G", "H"]
distances = np.array([[0, 15, 0, 0, 0, 0, 0, 0],
                      [15, 0, 10, 0, 0, 0, 0, 0],
                      [0, 10, 0, 17, 0, 0, 0, 0],
                      [0, 0, 17, 0, 12, 2, 0, 0],
                      [0, 0, 0, 12, 0, 10, 7, 0],
                      [0, 0, 0, 2, 10, 0, 0, 25],
                      [0, 0, 0, 0, 7, 0, 0, 11],
                      [0, 0, 0, 0, 0, 25, 11, 0]])

# Fitness function = Inverse of the total distance covered in the path
def fitness(path):
    total_distance = 0
    for i in range(len(path) - 1):
        total_distance += distances[nodes.index(path[i]), nodes.index(path[i + 1])]
    return (1 / total_distance)

# Genetic algorithm
def genetic_algorithm(pop_size, max_gen, crossover_rate, mutation_rate):
    
    population = []
    for i in range(pop_size):
        population.append(random.sample(nodes, len(nodes)))
    
    for gen in range(max_gen):
        
        print("Generation:", gen)
        # Evaluate the fitness of each individual
        fitness_values = []
        for individual in population:
            fitness_values.append(fitness(individual))
            
        
        best_fitness = max(fitness_values)
        best_individual = population[fitness_values.index(best_fitness)]
        print("Best fitness:", best_fitness)
        print("Best individual:", best_individual)
        
        if best_fitness == 1 / 58:
        
            print("Optimal solution found:", best_individual)
            return best_individual
        
        # Select pairs of individuals for reproduction based on their fitness
        mating_pool = []
        for i in range(pop_size):
            r = random.uniform(0, sum(fitness_values))
            s = 0
        
            for j in range(pop_size):
                s += fitness_values[j]
                # If the partial sum is greater than or equal to the random number, select that individual
                if s >= r:
                    mating_pool.append(population[j])
                    break
        # Apply crossover and mutation operators to generate new individuals
        offspring = []
        for i in range(0, pop_size, 2):
            parent1 = mating_pool[i]
            parent2 = mating_pool[i + 1]
            
            
            r = random.random()
            # If the random number < the crossover rate, then perform crossover
            if r < crossover_rate:
                cp = random.randint(1, len(nodes) - 2)
                child = []
                child.extend(parent1[:cp])
                for node in parent2:
                    if node not in child:
                        child.append(node)
                
                offspring.append(child)
            else:
                offspring.append(parent1)
            r = random.random()
            # If the random number < mutation rate, perform mutation
            if r < mutation_rate:
                
                i1 = random.randint(0, len(nodes) - 1)
                i2 = random.randint(0, len(nodes) - 1)
                # Swap the nodes at these indices
                offspring[-1][i1], offspring[-1][i2] = offspring[-1][i2], offspring[-1][i1]
        
        population = offspring
    # Return best individual and its fitness value
    return best_individual, best_fitness

# %% [markdown]
# ### DYNAMIC INPUT

# %% [markdown]
# IMPORTANT : Dynamic Input must be got in this section. Display the possible states to choose from:
# This is applicable for all the relevent problems as mentioned in the question.

# %%
#Code Block : Function & call to get inputs (start/end state)

# %% [markdown]
# ### 4.	Calling the search algorithms
# (For bidirectional search in below sections first part can be used as per Hint provided. Under second section other combinations as per Hint or your choice of 2 algorithms can be called .As an analyst suggest suitable approximation in the comparitive analysis section)

# %%
#Invoke algorithm 1 (Should Print the solution, path, cost etc., (As mentioned in the problem))


if __name__ == '__main__':
    
    num_nodes=8
    testGraph = Graph(num_nodes)    
    testGraph.generate_edges(num_nodes)
    
    # Now, test the algorithm    
    start = "A"
    goal = "H"
    testGraph.ida_star(start, goal)

# %%
#Invoke algorithm 2 (Should Print the solution, path, cost etc., (As mentioned in the problem))

# %% [markdown]
# ### 5.	Comparitive Analysis

# %%
#Code Block : Print the Time & Space complexity of algorithm 1

# %%
#Code Block : Print the Time & Space complexity of algorithm 2

# %% [markdown]
# ### 6.	Provide your comparitive analysis or findings in no more than 3 lines in below section

# %% [markdown]
# Comparison : _______________________________________________
#
# ________________________________________________________
#
# _________________________________________________________

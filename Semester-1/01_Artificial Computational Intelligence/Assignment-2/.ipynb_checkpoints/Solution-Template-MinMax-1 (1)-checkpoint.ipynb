# %% [markdown]
# ## Artificial and Computational Intelligence Assignment 2

# %% [markdown]
# ## Gaming with Min-Max Algorithm - Solution template

# %% [markdown]
# ### List only the BITS (Name) of active contributors in this assignment:
# 1. KASHYAP RAJPUROHIT (2023ab05027@wilp.bits-pilani.ac.in)
# 2. Vibhav Raman (2023aa05805@wilp.bits-pilani.ac.in)
# 3. Gundavarapu Sai Raghuram (2023ab05139)
# 4. ___________________
# 5. ___________________

# %% [markdown]
# # Things to follow
#
# 1. Use appropriate data structures to represent the graph using python libraries
# 2. Provide proper documentation
# 3. Create neat solution without error during game playing

# %% [markdown]
# ### Coding begins here

# %% [markdown]
# ### PEAS - Data structures and fringes that define the Agent environment goes here

# %%
board = [
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#']
    ]

# %% [markdown]
# ### Implementation of the Min-Max algorithm

# %%
#Code block of min max algo with alpha-beta pruning
def minimaxAlgo(board, words, depth, is_curr_player):
    if depth == 0 or not words:
        return evaluateScore(board), None
    
    if is_curr_player:
        best_score = float('-inf')
        best_move = None
        for word in words:
            for row in range(len(board)):
                for col in range(len(board[0])):
                    for direction in ["across", "down"]:
                        if is_valid_move(board, word, row, col, direction):
                            new_board = place_the_word(board, word, row, col, direction)
                            score, _ = minimaxAlgo(new_board, [w for w in words if w != word], depth - 1, False)
                            if score > best_score:
                                best_score = score
                                best_move = (word, row, col, direction)
        return best_score, best_move
    else:
        best_score = float('inf')
        best_move = None
        for word in words:
            for row in range(len(board)):
                for col in range(len(board[0])):
                    for direction in ["across", "down"]:
                        if is_valid_move(board, word, row, col, direction):
                            new_board = place_the_word(board, word, row, col, direction)
                            score, _ = minimaxAlgo(new_board, [w for w in words if w != word], depth - 1, True)
                            if score < best_score:
                                best_score = score
                                best_move = (word, row, col, direction)
        return best_score, best_move

# %% [markdown]
# ### Implementation of the alpha-beta pruning

# %% [markdown]
# ### Choice and implementation of the Static Evaluation Function.

# %%
def start_the_game(words):
    # board = [
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#'],
    #     ['#', '#', '#', '#', '#', '#', '#']
    # ]
    
    current_player = 1
    while words:
        displayPuzzle(board)
        print(f"Player {current_player}'s turn:")
        _, (word, row, col, direction) = minimaxAlgo(board, words, 2, current_player == 1)
        print(f"Placing '{word}' at ({row}, {col}) {direction}")
        board = place_the_word(board, word, row, col, direction)
        words.remove(word)
        current_player = 3 - current_player  # Switch player
        
    displayPuzzle(board)
    score_player1 = sum(row.count('#') for row in board)
    score_player2 = 49 - score_player1
    print(f"Player 1's score: {score_player1}")
    print(f"Player 2's score: {score_player2}")
    if score_player1 > score_player2:
        print("Player 1 wins!")
    elif score_player1 < score_player2:
        print("Player 2 wins!")
    else:
        print("It's a tie!")

# %%
#Code block - Start the game
start_the_game(words)

# %%
### Full Game in one Cell - Easy to execute

# %%
import copy

# Function to display the board
def displayPuzzle(board):
    for row in board:
        print(" ".join(row))
    print()

# Function to check if a word fits in a particular position on the board
def is_valid_move(board, word, row, col, direction):
    if direction == "across":
        return col + len(word) <= len(board[0]) and all(board[row][col + i] == '#' or board[row][col + i] == word[i] for i in range(len(word)))
    elif direction == "down":
        return row + len(word) <= len(board) and all(board[row + i][col] == '#' or board[row + i][col] == word[i] for i in range(len(word)))
    return False

# Function to place a word on the board
def place_the_word(board, word, row, col, direction):
    new_board = copy.deepcopy(board)
    if direction == "across":
        for i in range(len(word)):
            new_board[row][col + i] = word[i]
    elif direction == "down":
        for i in range(len(word)):
            new_board[row + i][col] = word[i]
    return new_board

# Function to evaluate the score of a board
def evaluateScore(board):
    score = 0
    for row in board:
        score += row.count('#')  # Counting the number of empty spaces
    return 100 - score  # Subtracting from 100 because we want to maximize the score

# Mini-max Algorithm with alpha-beta pruning
def minimaxAlgo(board, words, depth, is_max_player):
    if depth == 0 or not words:
        return evaluateScore(board), None
    
    if is_max_player:
        best_score = float('-inf')
        best_move = None
        for word in words:
            for row in range(len(board)):
                for col in range(len(board[0])):
                    for direction in ["across", "down"]:
                        if is_valid_move(board, word, row, col, direction):
                            new_board = place_the_word(board, word, row, col, direction)
                            score, _ = minimaxAlgo(new_board, [w for w in words if w != word], depth - 1, False)
                            if score > best_score:
                                best_score = score
                                best_move = (word, row, col, direction)
        return best_score, best_move
    else:
        best_score = float('inf')
        best_move = None
        for word in words:
            for row in range(len(board)):
                for col in range(len(board[0])):
                    for direction in ["across", "down"]:
                        if is_valid_move(board, word, row, col, direction):
                            new_board = place_the_word(board, word, row, col, direction)
                            score, _ = minimaxAlgo(new_board, [w for w in words if w != word], depth - 1, True)
                            if score < best_score:
                                best_score = score
                                best_move = (word, row, col, direction)
        return best_score, best_move

# Function to play the game
def start_the_game(words):
    board = [
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#'],
        ['#', '#', '#', '#', '#', '#', '#']
    ]
    
    current_player = 1
    while words:
        displayPuzzle(board)
        print(f"Player {current_player}'s turn:")
        _, (word, row, col, direction) = minimaxAlgo(board, words, 2, current_player == 1)
        print(f"Placing '{word}' at ({row}, {col}) {direction}")
        board = place_the_word(board, word, row, col, direction)
        words.remove(word)
        current_player = 3 - current_player  # Switch player
        
    displayPuzzle(board)
    score_player1 = sum(row.count('#') for row in board)
    score_player2 = 49 - score_player1
    print(f"Player 1's score: {score_player1}")
    print(f"Player 2's score: {score_player2}")
    if score_player1 > score_player2:
        print("Player 1 wins!")
    elif score_player1 < score_player2:
        print("Player 2 wins!")
    else:
        print("It's a tie!")

# Words to be placed on the board
# words = ["EAGLE", "DUCK", "DOG", "SWAN", "PEACOCK", "PARROT", "CROW"]
words = ["DUCK", "DOG", "SWAN", "PEACOCK", "PARROT", "CROW"]
# Play the game
start_the_game(words)
# Out:
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 1's turn:
# Placing 'PEACOCK' at (0, 0) across
# P E A C O C K
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 2's turn:
# Placing 'DOG' at (1, 0) across
# P E A C O C K
# D O G # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 1's turn:
# Placing 'PARROT' at (1, 3) down
# P E A C O C K
# D O G P # # #
# # # # A # # #
# # # # R # # #
# # # # R # # #
# # # # O # # #
# # # # T # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 2's turn:
# Placing 'DUCK' at (1, 0) down
# P E A C O C K
# D O G P # # #
# U # # A # # #
# C # # R # # #
# K # # R # # #
# # # # O # # #
# # # # T # # #
# # # # # # # #
# ...

# %%
words = ["EAGLE", "DUCK", "DOG", "SWAN", "PEACOCK", "PARROT", "CROW"]
# Play the game
start_the_game(words)
# Out:
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 1's turn:
# Placing 'PEACOCK' at (0, 0) across
# P E A C O C K
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 2's turn:
# Placing 'DOG' at (1, 0) across
# P E A C O C K
# D O G # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 1's turn:
# Placing 'PARROT' at (1, 3) down
# P E A C O C K
# D O G P # # #
# # # # A # # #
# # # # R # # #
# # # # R # # #
# # # # O # # #
# # # # T # # #
# # # # # # # #
# # # # # # # #
# # # # # # # #
#
# Player 2's turn:
# Placing 'EAGLE' at (2, 2) across
# P E A C O C K
# D O G P # # #
# # # E A G L E
# # # # R # # #
# # # # R # # #
# # # # O # # #
# # # # T # # #
# # # # # # # #
# ...

# %% [markdown]
# #1. Check if You Have a Dedicated GPU
#
# Run this command in Command Prompt (Windows) or Terminal (Mac/Linux):
#
# nvidia-smi

# %% [markdown]
# If you see details about an NVIDIA GPU (e.g., RTX 3060, GTX 1650, etc.), your laptop has a dedicated GPU.
#
# If you get an error like command not found, you don’t have an NVIDIA GPU or need to install NVIDIA drivers.

# %%
# !pip install torch
# Out:
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 2.4/204.1 MB 11.2 MB/s eta 0:00:18
#     --------------------------------------- 4.7/204.1 MB 11.9 MB/s eta 0:00:17
#    - -------------------------------------- 7.3/204.1 MB 11.9 MB/s eta 0:00:17
#    - -------------------------------------- 10.0/204.1 MB 11.7 MB/s eta 0:00:17
#    -- ------------------------------------- 12.6/204.1 MB 11.8 MB/s eta 0:00:17
#    -- ------------------------------------- 15.2/204.1 MB 11.8 MB/s eta 0:00:16
#    --- ------------------------------------ 17.3/204.1 MB 11.9 MB/s eta 0:00:16
#    --- ------------------------------------ 20.2/204.1 MB 11.8 MB/s eta 0:00:16
#    ---- ----------------------------------- 22.5/204.1 MB 11.8 MB/s eta 0:00:16
#    ---- ----------------------------------- 25.2/204.1 MB 11.8 MB/s eta 0:00:16
#    ----- ---------------------------------- 27.8/204.1 MB 11.8 MB/s eta 0:00:15
# ...

# %%
# Check if PyTorch Detects CUDA

import torch
print("CUDA Available:", torch.cuda.is_available())
print("CUDA Device Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "None")
# Out:
# CUDA Available: False
# CUDA Device Name: None

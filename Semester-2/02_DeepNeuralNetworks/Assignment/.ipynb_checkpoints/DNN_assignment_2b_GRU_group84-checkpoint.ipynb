# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# Load the dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"
data = pd.read_csv(url, usecols=[1])  # Only load the 'Passengers' column
data = data.values  # Convert to a numpy array
data = data.astype('float32')  # Ensure data is in float32 format

# Plot the dataset
plt.plot(data)
plt.title("Monthly Airline Passenger Numbers")
plt.xlabel("Time")
plt.ylabel("Passengers")
plt.show()

# Normalize the data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# Create sequences for the GRU
def create_sequences(data, time_steps):
    X, y = [], []
    for i in range(len(data) - time_steps):
        X.append(data[i:i + time_steps])
        y.append(data[i + time_steps])
    return np.array(X), np.array(y)

time_steps = 12  # Using past 12 months to predict the next month
X, y = create_sequences(scaled_data, time_steps)

# Split the data into training and testing sets (80% training, 20% testing)
train_size = int(len(X) * 0.8)
X_train, y_train = X[:train_size], y[:train_size]
X_test, y_test = X[train_size:], y[train_size:]

# Reshape the data for the GRU (samples, time steps, features)
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense

# Build the GRU model
model = Sequential()
model.add(GRU(50, activation='relu', input_shape=(time_steps, 1)))
model.add(Dense(1))  # Single output for regression

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

model.summary()

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test))
# Out:
# c:\Python3\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ gru_1 (GRU)                     │ (None, 50)             │         7,950 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,001 (31.25 KB)
#  Trainable params: 8,001 (31.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 10s 567ms/step - loss: 0.1250 - val_loss: 0.4244
# Epoch 2/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.1017 - val_loss: 0.3620
# Epoch 3/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0795 - val_loss: 0.3031
# Epoch 4/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0665 - val_loss: 0.2476
# Epoch 5/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 138ms/step - loss: 0.0477 - val_loss: 0.1979
# Epoch 6/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 0.0351 - val_loss: 0.1534
# Epoch 7/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0293 - val_loss: 0.1142
# Epoch 8/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0226 - val_loss: 0.0822
# Epoch 9/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - loss: 0.0128 - val_loss: 0.0589
# Epoch 10/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0128 - val_loss: 0.0448
# Epoch 11/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.0124 - val_loss: 0.0410
# Epoch 12/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0133 - val_loss: 0.0428
# Epoch 13/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0118 - val_loss: 0.0447
# Epoch 14/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - loss: 0.0095 - val_loss: 0.0442
# Epoch 15/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - loss: 0.0100 - val_loss: 0.0354
# Epoch 16/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0091 - val_loss: 0.0291
# Epoch 17/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - loss: 0.0090 - val_loss: 0.0259
# Epoch 18/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 0.0083 - val_loss: 0.0258
# Epoch 19/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0072 - val_loss: 0.0265
# Epoch 20/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0083 - val_loss: 0.0235
# Epoch 21/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.0074 - val_loss: 0.0219
# Epoch 22/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - loss: 0.0059 - val_loss: 0.0205
# Epoch 23/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0063 - val_loss: 0.0195
# Epoch 24/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0055 - val_loss: 0.0193
# Epoch 25/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - loss: 0.0063 - val_loss: 0.0192
# Epoch 26/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - loss: 0.0049 - val_loss: 0.0189
# Epoch 27/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0053 - val_loss: 0.0188
# Epoch 28/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0058 - val_loss: 0.0187
# Epoch 29/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0058 - val_loss: 0.0186
# Epoch 30/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 0.0050 - val_loss: 0.0186
# Epoch 31/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0045 - val_loss: 0.0185
# Epoch 32/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 177ms/step - loss: 0.0053 - val_loss: 0.0182
# Epoch 33/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0056 - val_loss: 0.0182
# Epoch 34/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0053 - val_loss: 0.0183
# Epoch 35/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0057 - val_loss: 0.0185
# Epoch 36/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0051 - val_loss: 0.0183
# Epoch 37/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - loss: 0.0043 - val_loss: 0.0182
# Epoch 38/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 0.0063 - val_loss: 0.0179
# Epoch 39/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.0055 - val_loss: 0.0181
# Epoch 40/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0050 - val_loss: 0.0181
# Epoch 41/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0048 - val_loss: 0.0178
# Epoch 42/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 0.0053 - val_loss: 0.0179
# Epoch 43/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0050 - val_loss: 0.0177
# Epoch 44/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0053 - val_loss: 0.0175
# Epoch 45/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - loss: 0.0055 - val_loss: 0.0172
# Epoch 46/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0048 - val_loss: 0.0172
# Epoch 47/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.0055 - val_loss: 0.0170
# Epoch 48/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 0.0049 - val_loss: 0.0169
# Epoch 49/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 69ms/step - loss: 0.0047 - val_loss: 0.0170
# Epoch 50/50
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.0044 - val_loss: 0.0173

# %%
# Make predictions
y_pred = model.predict(X_test)

# Inverse transform the predictions and actual values
y_actual = scaler.inverse_transform(y_test.reshape(-1, 1))
y_pred = scaler.inverse_transform(y_pred)

# Plot the predictions and actual values
plt.figure(figsize=(10, 6))
plt.plot(y_actual, label='True Value')
plt.plot(y_pred, label='Predicted Value')
plt.title('GRU Model Predictions vs. Actual Values')
plt.xlabel('Time')
plt.ylabel('Passengers')
plt.legend()
plt.show()

# Calculate evaluation metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error

mse = mean_squared_error(y_actual, y_pred)
rmse = np.sqrt(mse)
mae = mean_absolute_error(y_actual, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'Root Mean Squared Error: {rmse}')
print(f'Mean Absolute Error: {mae}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# Mean Squared Error: 4654.41748046875
# Root Mean Squared Error: 68.2232894897461
# Mean Absolute Error: 52.770633697509766

# %% [markdown]
# # Exercise
#
# - Use a different optimizer.
# - Train for more epochs.

# %%
# Compile the model using rmsprop optimizer
model.compile(optimizer='rmsprop', loss='mean_squared_error')

# Train the model for 100 epoch
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Make predictions
y_pred = model.predict(X_test)

# Inverse transform the predictions
y_pred = scaler.inverse_transform(y_pred)
# Out:
# Epoch 1/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 9s 589ms/step - loss: 0.0046 - val_loss: 0.0170
# Epoch 2/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0058 - val_loss: 0.0208
# Epoch 3/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0058 - val_loss: 0.0188
# Epoch 4/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 198ms/step - loss: 0.0054 - val_loss: 0.0194
# Epoch 5/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - loss: 0.0060 - val_loss: 0.0166
# Epoch 6/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.0050 - val_loss: 0.0168
# Epoch 7/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 0.0048 - val_loss: 0.0186
# Epoch 8/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0060 - val_loss: 0.0163
# Epoch 9/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0047 - val_loss: 0.0163
# Epoch 10/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - loss: 0.0049 - val_loss: 0.0163
# Epoch 11/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - loss: 0.0047 - val_loss: 0.0162
# Epoch 12/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - loss: 0.0048 - val_loss: 0.0161
# Epoch 13/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.0046 - val_loss: 0.0156
# Epoch 14/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0053 - val_loss: 0.0157
# Epoch 15/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0050 - val_loss: 0.0156
# Epoch 16/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0048 - val_loss: 0.0173
# Epoch 17/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0046 - val_loss: 0.0167
# Epoch 18/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.0049 - val_loss: 0.0193
# Epoch 19/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - loss: 0.0052 - val_loss: 0.0158
# Epoch 20/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0051 - val_loss: 0.0160
# Epoch 21/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0044 - val_loss: 0.0157
# Epoch 22/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - loss: 0.0053 - val_loss: 0.0152
# Epoch 23/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 178ms/step - loss: 0.0041 - val_loss: 0.0152
# Epoch 24/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - loss: 0.0045 - val_loss: 0.0166
# Epoch 25/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step - loss: 0.0042 - val_loss: 0.0151
# Epoch 26/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - loss: 0.0051 - val_loss: 0.0153
# Epoch 27/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 0.0045 - val_loss: 0.0192
# Epoch 28/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 0.0050 - val_loss: 0.0152
# Epoch 29/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0040 - val_loss: 0.0149
# Epoch 30/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: 0.0048 - val_loss: 0.0151
# Epoch 31/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0048 - val_loss: 0.0181
# Epoch 32/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0049 - val_loss: 0.0166
# Epoch 33/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 0.0061 - val_loss: 0.0148
# Epoch 34/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 0.0044 - val_loss: 0.0203
# Epoch 35/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 0.0057 - val_loss: 0.0148
# Epoch 36/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0043 - val_loss: 0.0147
# Epoch 37/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - loss: 0.0042 - val_loss: 0.0173
# Epoch 38/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - loss: 0.0057 - val_loss: 0.0154
# Epoch 39/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 0.0044 - val_loss: 0.0146
# Epoch 40/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0048 - val_loss: 0.0150
# Epoch 41/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0046 - val_loss: 0.0163
# Epoch 42/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - loss: 0.0044 - val_loss: 0.0148
# Epoch 43/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 179ms/step - loss: 0.0047 - val_loss: 0.0161
# Epoch 44/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 0.0044 - val_loss: 0.0145
# Epoch 45/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0050 - val_loss: 0.0147
# Epoch 46/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 215ms/step - loss: 0.0042 - val_loss: 0.0150
# Epoch 47/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 0.0040 - val_loss: 0.0158
# Epoch 48/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.0039 - val_loss: 0.0141
# Epoch 49/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.0043 - val_loss: 0.0140
# Epoch 50/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0040 - val_loss: 0.0153
# Epoch 51/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 0.0039 - val_loss: 0.0140
# Epoch 52/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 73ms/step - loss: 0.0045 - val_loss: 0.0139
# Epoch 53/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 63ms/step - loss: 0.0043 - val_loss: 0.0139
# Epoch 54/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 0.0043 - val_loss: 0.0144
# Epoch 55/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 273ms/step - loss: 0.0047 - val_loss: 0.0143
# Epoch 56/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0044 - val_loss: 0.0165
# Epoch 57/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.0048 - val_loss: 0.0140
# Epoch 58/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 210ms/step - loss: 0.0035 - val_loss: 0.0140
# Epoch 59/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 174ms/step - loss: 0.0052 - val_loss: 0.0158
# Epoch 60/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - loss: 0.0050 - val_loss: 0.0137
# Epoch 61/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0042 - val_loss: 0.0138
# Epoch 62/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0044 - val_loss: 0.0136
# Epoch 63/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.0039 - val_loss: 0.0135
# Epoch 64/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 0.0041 - val_loss: 0.0158
# Epoch 65/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 0.0060 - val_loss: 0.0136
# Epoch 66/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0040 - val_loss: 0.0134
# Epoch 67/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.0043 - val_loss: 0.0132
# Epoch 68/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 0.0039 - val_loss: 0.0131
# Epoch 69/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - loss: 0.0046 - val_loss: 0.0145
# Epoch 70/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0042 - val_loss: 0.0132
# Epoch 71/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0040 - val_loss: 0.0130
# Epoch 72/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0039 - val_loss: 0.0129
# Epoch 73/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - loss: 0.0042 - val_loss: 0.0151
# Epoch 74/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - loss: 0.0042 - val_loss: 0.0149
# Epoch 75/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0041 - val_loss: 0.0152
# Epoch 76/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0036 - val_loss: 0.0129
# Epoch 77/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0039 - val_loss: 0.0141
# Epoch 78/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - loss: 0.0041 - val_loss: 0.0126
# Epoch 79/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 0.0036 - val_loss: 0.0132
# Epoch 80/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0038 - val_loss: 0.0134
# Epoch 81/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.0043 - val_loss: 0.0125
# Epoch 82/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 192ms/step - loss: 0.0039 - val_loss: 0.0158
# Epoch 83/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 165ms/step - loss: 0.0044 - val_loss: 0.0129
# Epoch 84/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - loss: 0.0043 - val_loss: 0.0134
# Epoch 85/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0038 - val_loss: 0.0125
# Epoch 86/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 0.0040 - val_loss: 0.0126
# Epoch 87/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 0.0036 - val_loss: 0.0123
# Epoch 88/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.0040 - val_loss: 0.0124
# Epoch 89/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.0037 - val_loss: 0.0126
# Epoch 90/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 0.0039 - val_loss: 0.0134
# Epoch 91/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.0040 - val_loss: 0.0131
# Epoch 92/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.0038 - val_loss: 0.0128
# Epoch 93/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 0.0038 - val_loss: 0.0128
# Epoch 94/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 0.0038 - val_loss: 0.0123
# Epoch 95/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - loss: 0.0038 - val_loss: 0.0162
# Epoch 96/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - loss: 0.0051 - val_loss: 0.0157
# Epoch 97/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 197ms/step - loss: 0.0037 - val_loss: 0.0116
# Epoch 98/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.0035 - val_loss: 0.0124
# Epoch 99/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 0.0037 - val_loss: 0.0115
# Epoch 100/100
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 143ms/step - loss: 0.0040 - val_loss: 0.0120
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step

# %%
# Plot the predictions and actual values
plt.figure(figsize=(10, 6))
plt.plot(y_actual, label='True Value')
plt.plot(y_pred, label='Predicted Value')
plt.title('GRU Model Predictions vs. Actual Values')
plt.xlabel('Time')
plt.ylabel('Passengers')
plt.legend()
plt.show()

rmse = np.sqrt(mean_squared_error(y_actual, y_pred))
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 56.85415267944336

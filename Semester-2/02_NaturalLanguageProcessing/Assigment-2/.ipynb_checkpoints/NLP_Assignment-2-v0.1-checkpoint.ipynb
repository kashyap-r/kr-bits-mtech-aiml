# %% [markdown]
# ## **Task 1**
# <!--  -->
# EDA includes two steps
# 1. Data Load and Summarization
#    - Load the dataset and check the first few rows to understand its structure.
#    - Print the summary statistics / desriptive statistics
#    - distribution of the Sentiment - a historgram / barchart to understand the class balance
#    - Text Length Analysis - Analyze the length of news headlines to understand the distribution of text
#      lengths.
#    - Word Cloud - Generate a word cloud to visualize the most common words in the news headlines.
#
# 2. Pre-processing
#    Text Cleaning and Normalization
#         Text Cleaning - Clean the text by removing punctuation, converting to lowercase, and removing stopwords.
#         Text Normalization - helps in reducing the complexity and variability in the text data.
#         Converting text to a standard format. This can include converting accented characters to their non-accented counterparts, handling special
#            characters, etc.
#
#     1. Handling Missing Values - Drop or fill missing values if any.
#     2. Lowercasing - Converting all characters to lowercase to ensure uniformity.
#     3. Removing Punctuation - Eliminating punctuation marks from the text.
#     4. Removing Stopwords - Removing common words that do not contribute much to the meaning (e.g., “and”, “the”).
#     5. Removing Numbers - Eliminating numerical values from the text.
#     6. Stemming - Reducing words to their root form. For example, “running” becomes “run”.
#     7. Lemmatization - Reducing words to their base or dictionary form. For example, “better” becomes “good”.
#     8. Handling Contractions - Expanding contractions to their full form. For example, “don’t” becomes “do not”.
#     9. Removing Extra Whitespace - Removing leading, trailing, and extra spaces between words.
#     10. Removing Accented Characters - Convert accented characters to their non-accented counterparts.
#     11. Removing Special Characters - Remove special characters from the text.
#     12. Tokenization - Splitting text into individual words or tokens. This can be done at the word level or sentence level.
#     13. Encoding Sentiment = Encode the sentiment column if it’s categorical.

# %%
# !pip install numpy pandas matplotlib pillow wordcloud
# !pip install nltk spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in c:\users\usha_\appdata\roaming\python\python311\site-packages (1.24.4)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: matplotlib in c:\users\usha_\appdata\roaming\python\python311\site-packages (3.8.3)
# Requirement already satisfied: pillow in c:\users\usha_\appdata\roaming\python\python311\site-packages (10.1.0)
# Requirement already satisfied: wordcloud in c:\users\usha_\appdata\roaming\python\python311\site-packages (1.9.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from matplotlib) (4.49.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: nltk in d:\anaconda3\lib\site-packages (3.8.1)
# Requirement already satisfied: spacy in c:\users\usha_\appdata\roaming\python\python311\site-packages (3.7.4)
# Requirement already satisfied: click in c:\users\usha_\appdata\roaming\python\python311\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\usha_\appdata\roaming\python\python311\site-packages (from nltk) (1.1.1)
# Requirement already satisfied: regex>=2021.8.3 in d:\anaconda3\lib\site-packages (from nltk) (2023.10.3)
# Requirement already satisfied: tqdm in d:\anaconda3\lib\site-packages (from nltk) (4.65.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\usha_\appdata\roaming\python\python311\site-packages (from tqdm->nltk) (0.4.6)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)

# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np


from wordcloud import WordCloud

import warnings
warnings.filterwarnings('ignore')

# %%
colnames = ['sentiment', 'news_headline']
df = pd.read_csv("all-data.csv",  names=colnames, encoding="windows_1258")
df.style
# get the first 2000 rows
# df2k = df.head(2000)
df2k = df.iloc[:2000, :]

# %% [markdown]
# 2. Summary Statistics
#
#
# Describe the dataset to get summary statistics for numerical columns (if any).

# %%
df.describe()
# Out:
#        sentiment                                      news_headline
# count       4846                                               4846
# unique         3                                               4838
# top      neutral  TELECOMWORLDWIRE-7 April 2006-TJ Group Plc sel...
# freq        2879                                                  2

# %% [markdown]
# 3. Distribution of Sentiment
#
# Visualize the distribution of the sentiment column to understand the class balance.

# %%
# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot on the first subplot using Seaborn
sns.countplot(x='sentiment', data=df, ax=ax1)
ax1.set_title('Full Dataset')

# Plot on the second subplot using Seaborn
sns.countplot(x='sentiment', data=df2k, ax=ax2)
ax2.set_title('2K rows dataset')

# Display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# Text Length Analysis
# Analyze the length of news headlines to understand the distribution of text lengths.

# %%
df['headline_length'] = df['news_headline'].apply(len)
df2k['headline_length'] = df2k['news_headline'].apply(len)
# Create a figure with two subplots side by side
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Plot on the first subplot using Seaborn
sns.histplot(df['headline_length'], bins=20, ax=ax1, kde=True, color='seagreen')
ax1.set_title('Full Dataset')

# Plot on the second subplot using Seaborn
sns.histplot(df2k['headline_length'], bins=20, ax=ax2, kde=True, color='blue')
ax2.set_title('2K rows dataset')

# Display the plots
plt.tight_layout()
plt.show()

# %%
df.head(3)
# Out:
#   sentiment                                      news_headline  \
# 0   neutral  According to Gran , the company has no plans t...
# 1   neutral  Technopolis plans to develop in stages an area...
# 2  negative  The international electronic industry company ...
#
#    headline_length
# 0              127
# 1              190
# 2              228

# %% [markdown]
# e. Word Cloud
# Generate a word cloud to visualize the most common words in the news headlines.

# %%
# Combine all headlines into a single string
all_headlines = ' '.join(df['news_headline'])
all_headlines_2k = ' '.join(df2k['news_headline'])

# Generate the word cloud
wordcloud1 = WordCloud(width=800, 
                       height=400, 
                       background_color='white', 
                       colormap='viridis'
                      ).generate(all_headlines)

wordcloud2 = WordCloud(width=800,
                       height=400,
                       max_font_size=100,
                       min_font_size=10,
                       background_color='white',
                       colormap='plasma'
                      ).generate(all_headlines_2k)

# Plot the word clouds side by side
# fig, axes = plt.subplots(1, 2, figsize=(10, 5))
# Plot the word clouds one below the other
fig, axes = plt.subplots(2, 1, figsize=(10, 10))

# Display the first word cloud
axes[0].imshow(wordcloud1, interpolation="bilinear")
axes[0].axis("off")
axes[0].set_title('Word Cloud - Full Dataset')
# Display the second word cloud
axes[1].imshow(wordcloud2, interpolation="bilinear")
axes[1].axis("off")
axes[1].set_title('Word Cloud - 2k Dataset')

plt.show()

# %% [markdown]
# # 2. Preprocessing Steps

# %% [markdown]
# Text Cleaning and Normalization
# Text Cleaning - Clean the text by removing punctuation, converting to lowercase, and removing stopwords.
# Text Normalization - helps in reducing the complexity and variability in the text data.
# Converting text to a standard format. This can include converting accented characters to their non-accented counterparts, handling special characters, etc.
#
# 1. Handling Missing Values - Drop or fill missing values if any.
# 2. Lowercasing - Converting all characters to lowercase to ensure uniformity.
# 3. Removing Punctuation - Eliminating punctuation marks from the text.
# 4. Removing Stopwords - Removing common words that do not contribute much to the meaning (e.g., “and”, “the”).
# 5. Removing Numbers - Eliminating numerical values from the text.
# 6. Stemming - Reducing words to their root form. For example, “running” becomes “run”.
# 7. Lemmatization - Reducing words to their base or dictionary form. For example, “better” becomes “good”.
# 8. Handling Contractions - Expanding contractions to their full form. For example, “don’t” becomes “do not”.
# 9. Removing Extra Whitespace - Removing leading, trailing, and extra spaces between words.
# 10. Removing Accented Characters - Convert accented characters to their non-accented counterparts.
# 11. Removing Special Characters - Remove special characters from the text.
# 12.  Tokenization - Splitting text into individual words or tokens. This can be done at the word level or sentence level.
#
# 13. Encoding Sentiment = Encode the sentiment column if it’s categorical.

# %%
import string
# Download stopwords if not already downloaded
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\usha_\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\usha_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\usha_\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %% [markdown]
# 1. Handling Missing Values - Drop or fill missing values if any.
#
#     Drop rows with missing values
#     Alternatively, fill missing values
#     df['news headline'].fillna('', inplace=True)

# %%
# Handling missing values - Drop rows with missing values
df2k.dropna(inplace=True)

# %% [markdown]
# 2. Lowercasing - Converting all characters to lowercase to ensure uniformity.
# 3. Removing Punctuation - Eliminating punctuation marks from the text.

# %%
import string
# convert all characters to lowercase
df2k ['news_headline'] = df2k ['news_headline'].str.lower()
print(df2k ['news_headline'].head(5))

df2k ['news_headline'] = df2k ['news_headline'].str.translate(str.maketrans('', '', string.punctuation))
print(df2k ['news_headline'].head(5))
# Out:
# 0    according to gran , the company has no plans t...
# 1    technopolis plans to develop in stages an area...
# 2    the international electronic industry company ...
# 3    with the new production plant the company woul...
# 4    according to the company 's updated strategy f...
# Name: news_headline, dtype: object
# 0    according to gran  the company has no plans to...
# 1    technopolis plans to develop in stages an area...
# 2    the international electronic industry company ...
# 3    with the new production plant the company woul...
# 4    according to the company s updated strategy fo...
# Name: news_headline, dtype: object

# %% [markdown]
# 4. Removing Stopwords - Removing common words that do not contribute much to the meaning (e.g., “and”, “the”).
# 5. Removing Numbers - Eliminating numerical values from the text.

# %%
stop_words = set(stopwords.words('english'))

def clean_text(text):
    # Remove punctuation
    text = text.translate(str.maketrans('', '', string.punctuation))
    # Convert to lowercase
    text = text.lower()
    # Remove stopwords
    text = ' '.join(word for word in text.split() if word not in stop_words)
    return text

df2k['cleaned_headline'] = df2k['news_headline'].apply(clean_text)

# %%
# removing numbers 
import re
df2k['cleaned_headline'] = df2k['cleaned_headline'].str.replace(r'\d+', '', regex=True)

# %% [markdown]
# 6. Stemming - Reducing words to their root form. For example, “running” becomes “run”.
# 7. Lemmatization - Reducing words to their base or dictionary form. For example, “better” becomes “good”.
# 8.  Tokenization - Splitting text into individual words or tokens. This can be done at the word level or sentence level.

# %% [markdown]
# #### Tokenizing, Stemming, and Lemmatizing
#
# Tokenizing: Splits the text into individual words or tokens. Ex. word_tokenize: Tokenizes the text into words.
#
# Stemming: Reduces words to their root for  Ex.
# PorterStemmer: A common stemming algorithm
#
# .
# Lemmatizing: Reduces words to their base or dictionary   r
#     m.
# nlp(x): Processes the text using spaCy’s languag    d    el.
# token.lemma_: Extracts the lemma of eac.
# 4.

# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in c:\users\usha_\appdata\roaming\python\python311\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\usha_\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

# import spacy
# spacy.cli.download('en_core_web_sm')
# # Load spaCy model
# nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\usha_\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\usha_\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\usha_\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Using NLTK for Tokenizing and Stemming
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer

# Initialize the stemmer
stemmer = PorterStemmer()

# Tokenize and stem the 'Text' column
df2k['Tokenized'] = df2k['cleaned_headline'].apply(word_tokenize)
df2k['Stemmed'] = df2k['Tokenized'].apply(lambda x: [stemmer.stem(word) for word in x])

print(df2k)

# %%
# Using spaCy for Lemmatizing
# import spacy
# # Lemmatize the 'Text' column
# df2k['Lemmatized'] = df2k['cleaned_headline'].apply(lambda x: [token.lemma_ for token in nlp(x)])
# print(df2k)

# %%
lemmatizer = WordNetLemmatizer()

def tokenize_and_lemmatize(text):
    tokens = word_tokenize(text)
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return ' '.join(lemmatized_tokens)

df2k['processed_headline'] = df2k['cleaned_headline'].apply(tokenize_and_lemmatize)

# %%
df2k['processed_headline'].head(5)
# Out:
# 0    according gran company plan move production ru...
# 1    technopolis plan develop stage area le square ...
# 2    international electronic industry company elco...
# 3    new production plant company would increase ca...
# 4    according company updated strategy year baswar...
# Name: processed_headline, dtype: object

# %% [markdown]
# 8. Handling Contractions - Expanding contractions to their full form. For example, “don’t” becomes “do not”.
# 9. Removing Extra Whitespace - Removing leading, trailing, and extra spaces between words.
# 10. Removing Accented Characters - Convert accented characters to their non-accented counterparts.
# 11. Removing Special Characters - Remove special characters from the text.

# %%
# !pip install contractions
# Out:
# Defaulting to user installation because normal site-packages is not writeable
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [48 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-e0jwr6p5\language-check_7ecfe65bae6242b1864523195320beec\setup.py", line 595, in <module>
#       sys.exit(main())
#                ^^^^^^
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-e0jwr6p5\language-check_7ecfe65bae6242b1864523195320beec\setup.py", line 590, in main
#       run_setup_hooks(config)
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-e0jwr6p5\language-check_7ecfe65bae6242b1864523195320beec\setup.py", line 561, in run_setup_hooks
#       language_tool_hook(config)
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-e0jwr6p5\language-check_7ecfe65bae6242b1864523195320beec\setup.py", line 584, in language_tool_hook
#       download_lt()
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-e0jwr6p5\language-check_7ecfe65bae6242b1864523195320beec\download_lt.py", line 128, in download_lt
#       with closing(urlopen(url)) as u:
#                    ^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 216, in urlopen
#       return opener.open(url, data, timeout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 525, in open
#       response = meth(req, response)
#                  ^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 634, in http_response
#       response = self.parent.error(
#                  ^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 557, in error
#       result = self._call_chain(*args)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 496, in _call_chain
#       result = func(*args)
#                ^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 749, in http_error_302
#       return self.parent.open(new, timeout=req.timeout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 525, in open
#       response = meth(req, response)
#                  ^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 634, in http_response
#       response = self.parent.error(
#                  ^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 563, in error
#       return self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 496, in _call_chain
#       result = func(*args)
#                ^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 643, in http_error_default
#       raise HTTPError(req.full_url, code, msg, hdrs, fp)
#   urllib.error.HTTPError: HTTP Error 403: Forbidden
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for language-check
# ERROR: Could not build wheels for language-check, which is required to install pyproject.toml-based projects
# Collecting pycontractions
#   Using cached pycontractions-2.0.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: gensim>=2.0 in d:\anaconda3\lib\site-packages (from pycontractions) (4.3.0)
# Collecting language-check>=1.0 (from pycontractions)
#   Using cached language-check-1.1.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyemd>=0.4.4 (from pycontractions)
#   Using cached pyemd-1.0.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim>=2.0->pycontractions) (1.24.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim>=2.0->pycontractions) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda3\lib\site-packages (from gensim>=2.0->pycontractions) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim>=2.0->pycontractions) (2.0.9)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2.1.4)
# Requirement already satisfied: pyfume in c:\users\usha_\appdata\roaming\python\python311\site-packages (from FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (0.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2023.3)
# Requirement already satisfied: simpful==2.12.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2.12.0)
# Requirement already satisfied: fst-pso==1.8.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (1.8.1)
# Collecting pandas (from FuzzyTM>=0.4.0->gensim>=2.0->pycontractions)
#   Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: miniful in c:\users\usha_\appdata\roaming\python\python311\site-packages (from fst-pso==1.8.1->pyfume->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (0.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (1.16.0)
# Using cached pycontractions-2.0.1-py3-none-any.whl (9.6 kB)
# Using cached pyemd-1.0.0-cp311-cp311-win_amd64.whl (147 kB)
# Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
# Building wheels for collected packages: language-check
#   Building wheel for language-check (setup.py): started
#   Building wheel for language-check (setup.py): finished with status 'error'
#   Running setup.py clean for language-check
# Failed to build language-check

# %%
# !pip install pycontractions
# !pip install gensim pyemd language-check
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pycontractions
#   Using cached pycontractions-2.0.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: gensim>=2.0 in d:\anaconda3\lib\site-packages (from pycontractions) (4.3.0)
# Collecting language-check>=1.0 (from pycontractions)
#   Using cached language-check-1.1.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting pyemd>=0.4.4 (from pycontractions)
#   Using cached pyemd-1.0.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim>=2.0->pycontractions) (1.24.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim>=2.0->pycontractions) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda3\lib\site-packages (from gensim>=2.0->pycontractions) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim>=2.0->pycontractions) (2.0.9)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2.1.4)
# Requirement already satisfied: pyfume in c:\users\usha_\appdata\roaming\python\python311\site-packages (from FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (0.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2023.3)
# Requirement already satisfied: simpful==2.12.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (2.12.0)
# Requirement already satisfied: fst-pso==1.8.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (1.8.1)
# Collecting pandas (from FuzzyTM>=0.4.0->gensim>=2.0->pycontractions)
#   Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: miniful in c:\users\usha_\appdata\roaming\python\python311\site-packages (from fst-pso==1.8.1->pyfume->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (0.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim>=2.0->pycontractions) (1.16.0)
# Using cached pycontractions-2.0.1-py3-none-any.whl (9.6 kB)
# Using cached pyemd-1.0.0-cp311-cp311-win_amd64.whl (147 kB)
# Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
# Building wheels for collected packages: language-check
#   Building wheel for language-check (setup.py): started
#   Building wheel for language-check (setup.py): finished with status 'error'
#   Running setup.py clean for language-check
# Failed to build language-check
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [48 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-j1o3l8ip\language-check_d541d43b1dab44fbb37ef2be2dc77c27\setup.py", line 595, in <module>
#       sys.exit(main())
#                ^^^^^^
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-j1o3l8ip\language-check_d541d43b1dab44fbb37ef2be2dc77c27\setup.py", line 590, in main
#       run_setup_hooks(config)
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-j1o3l8ip\language-check_d541d43b1dab44fbb37ef2be2dc77c27\setup.py", line 561, in run_setup_hooks
#       language_tool_hook(config)
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-j1o3l8ip\language-check_d541d43b1dab44fbb37ef2be2dc77c27\setup.py", line 584, in language_tool_hook
#       download_lt()
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-j1o3l8ip\language-check_d541d43b1dab44fbb37ef2be2dc77c27\download_lt.py", line 128, in download_lt
#       with closing(urlopen(url)) as u:
#                    ^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 216, in urlopen
#       return opener.open(url, data, timeout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 525, in open
#       response = meth(req, response)
#                  ^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 634, in http_response
#       response = self.parent.error(
#                  ^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 557, in error
#       result = self._call_chain(*args)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 496, in _call_chain
#       result = func(*args)
#                ^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 749, in http_error_302
#       return self.parent.open(new, timeout=req.timeout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 525, in open
#       response = meth(req, response)
#                  ^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 634, in http_response
#       response = self.parent.error(
#                  ^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 563, in error
#       return self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 496, in _call_chain
#       result = func(*args)
#                ^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 643, in http_error_default
#       raise HTTPError(req.full_url, code, msg, hdrs, fp)
#   urllib.error.HTTPError: HTTP Error 403: Forbidden
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for language-check
# ERROR: Could not build wheels for language-check, which is required to install pyproject.toml-based projects
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: gensim in d:\anaconda3\lib\site-packages (4.3.0)
# Collecting pyemd
#   Using cached pyemd-1.0.0-cp311-cp311-win_amd64.whl.metadata (9.9 kB)
# Collecting language-check
#   Using cached language-check-1.1.tar.gz (33 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: numpy>=1.18.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim) (1.24.4)
# Requirement already satisfied: scipy>=1.7.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim) (1.10.1)
# Requirement already satisfied: smart-open>=1.8.1 in d:\anaconda3\lib\site-packages (from gensim) (5.2.1)
# Requirement already satisfied: FuzzyTM>=0.4.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from gensim) (2.0.9)
# Requirement already satisfied: pandas in d:\anaconda3\lib\site-packages (from FuzzyTM>=0.4.0->gensim) (2.1.4)
# Requirement already satisfied: pyfume in c:\users\usha_\appdata\roaming\python\python311\site-packages (from FuzzyTM>=0.4.0->gensim) (0.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pandas->FuzzyTM>=0.4.0->gensim) (2023.3)
# Requirement already satisfied: simpful==2.12.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (2.12.0)
# Requirement already satisfied: fst-pso==1.8.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pyfume->FuzzyTM>=0.4.0->gensim) (1.8.1)
# Collecting pandas (from FuzzyTM>=0.4.0->gensim)
#   Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl.metadata (12 kB)
# Requirement already satisfied: miniful in c:\users\usha_\appdata\roaming\python\python311\site-packages (from fst-pso==1.8.1->pyfume->FuzzyTM>=0.4.0->gensim) (0.0.6)
# Requirement already satisfied: six>=1.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas->FuzzyTM>=0.4.0->gensim) (1.16.0)
# Using cached pyemd-1.0.0-cp311-cp311-win_amd64.whl (147 kB)
# Using cached pandas-1.5.3-cp311-cp311-win_amd64.whl (10.3 MB)
# Building wheels for collected packages: language-check
#   Building wheel for language-check (setup.py): started
#   Building wheel for language-check (setup.py): finished with status 'error'
#   Running setup.py clean for language-check
# Failed to build language-check
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [48 lines of output]
#   Traceback (most recent call last):
#     File "<string>", line 2, in <module>
#     File "<pip-setuptools-caller>", line 34, in <module>
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-cpxltg3d\language-check_43badae3d6e445ce9eb54ce1c0e6e981\setup.py", line 595, in <module>
#       sys.exit(main())
#                ^^^^^^
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-cpxltg3d\language-check_43badae3d6e445ce9eb54ce1c0e6e981\setup.py", line 590, in main
#       run_setup_hooks(config)
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-cpxltg3d\language-check_43badae3d6e445ce9eb54ce1c0e6e981\setup.py", line 561, in run_setup_hooks
#       language_tool_hook(config)
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-cpxltg3d\language-check_43badae3d6e445ce9eb54ce1c0e6e981\setup.py", line 584, in language_tool_hook
#       download_lt()
#     File "C:\Users\usha_\AppData\Local\Temp\pip-install-cpxltg3d\language-check_43badae3d6e445ce9eb54ce1c0e6e981\download_lt.py", line 128, in download_lt
#       with closing(urlopen(url)) as u:
#                    ^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 216, in urlopen
#       return opener.open(url, data, timeout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 525, in open
#       response = meth(req, response)
#                  ^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 634, in http_response
#       response = self.parent.error(
#                  ^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 557, in error
#       result = self._call_chain(*args)
#                ^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 496, in _call_chain
#       result = func(*args)
#                ^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 749, in http_error_302
#       return self.parent.open(new, timeout=req.timeout)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 525, in open
#       response = meth(req, response)
#                  ^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 634, in http_response
#       response = self.parent.error(
#                  ^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 563, in error
#       return self._call_chain(*args)
#              ^^^^^^^^^^^^^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 496, in _call_chain
#       result = func(*args)
#                ^^^^^^^^^^^
#     File "D:\anaconda3\Lib\urllib\request.py", line 643, in http_error_default
#       raise HTTPError(req.full_url, code, msg, hdrs, fp)
#   urllib.error.HTTPError: HTTP Error 403: Forbidden
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for language-check
# ERROR: Could not build wheels for language-check, which is required to install pyproject.toml-based projects

# %%
# Expanding Contractions
import contractions

def expand_contractions(text):
    return contractions.fix(text)

df2k['processed_headline'] = df2k['processed_headline'].apply(expand_contractions)
print(df2k['processed_headline'].head(5))  # Output: "I do not like this."
# Out:
# 0    according gran company plan move production ru...
# 1    technopolis plan develop stage area le square ...
# 2    international electronic industry company elco...
# 3    new production plant company would increase ca...
# 4    according company updated strategy year baswar...
# Name: processed_headline, dtype: object

# %%
# import gensim.downloader as api
# from pycontractions import Contractions
# import pandas as pd

# # Load the GloVe model
# model = api.load("glove-twitter-100")
# # Initialize the Contractions object
# cont = Contractions(kv_model=model)
# cont.load_models()
# # Sample DataFrame
# data = {'Text': ["I don't know", "She's going to the market", "We'll see what happens"]}
# df = pd.DataFrame(data)
# # Function to expand contractions
# def expand_contractions(text):
#     return list(cont.expand_texts([text], precise=True))[0]
# # Apply the function to the 'Text' column
# df2k['Expanded_Text'] = df2k['processed_headline'].apply(expand_contractions)
# # Display the modified DataFrame
# print(df2k)

# %%
# 9. Removing Extra Whitespace
# Removing leading, trailing, and extra spaces between words.

# Function to remove leading, trailing, and extra spaces between words
def clean_text(text):
    # Remove leading and trailing spaces
    text = text.strip()
    # Remove extra spaces between words
    text = ' '.join(text.split())
    return text

print(df2k['processed_headline'].head(5)) 
df2k['processed_headline'] = df2k['processed_headline'].apply(clean_text)
print(df2k['processed_headline'].head(5))
# Out:
# 0    according gran company plan move production ru...
# 1    technopolis plan develop stage area le square ...
# 2    international electronic industry company elco...
# 3    new production plant company would increase ca...
# 4    according company updated strategy year baswar...
# Name: processed_headline, dtype: object
# 0    according gran company plan move production ru...
# 1    technopolis plan develop stage area le square ...
# 2    international electronic industry company elco...
# 3    new production plant company would increase ca...
# 4    according company updated strategy year baswar...
# Name: processed_headline, dtype: object

# %%
# !pip install unicode
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting unicode
#   Downloading unicode-2.9-py2.py3-none-any.whl.metadata (1.1 kB)
# Downloading unicode-2.9-py2.py3-none-any.whl (14 kB)
# Installing collected packages: unicode
# Successfully installed unicode-2.9

# %%
# Removing Accented Characters
import unicodedata

def remove_accent_spl_char(text):
    # text = "Café"
    normalized_text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('utf-8')
    normalized_text = normalized_text = re.sub(r'[^A-Za-z0-9\s]', '', text)
    return normalized_text
    
df2k['processed_headline'] = df2k['processed_headline'].apply(remove_accent_spl_char)
print(df2k['processed_headline'].head(5))
# Out:
# 0    according gran company plan move production ru...
# 1    technopolis plan develop stage area le square ...
# 2    international electronic industry company elco...
# 3    new production plant company would increase ca...
# 4    according company updated strategy year baswar...
# Name: processed_headline, dtype: object

# %% [markdown]
# 13. Encoding Sentiment = Encode the sentiment column if it’s categorical.

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
df['encoded_sentiment'] = label_encoder.fit_transform(df['sentiment'])

# %%
from collections import Counter

all_words = df2k['processed_headline'].str.split().explode()
# print (f"all_words: {all_words}")
word_frequency = Counter(all_words)
print (f"word_frequncy: {word_frequncy}")
word_freq_df = pd.DataFrame(word_frequency.items(), columns=['Word', 'Frequency']).sort_values(by='Frequency', ascending=False)
# Out:
# word_frequncy: Counter({'eur': 581, 'company': 377, 'said': 256, 'mn': 246, 'finnish': 227, 'sale': 225, 'million': 194, 'net': 174, 'service': 171, 'share': 169, 'profit': 165, 'year': 158, 'market': 147, 'new': 137, 'mln': 137, 'group': 133, 'period': 132, 'operating': 124, 'finland': 122, 'quarter': 106, 'euro': 104, 'business': 103, 'oyj': 101, 'also': 97, 'rose': 96, 'increased': 89, 'product': 88, 'first': 82, 'increase': 81, 'solution': 79, 'technology': 74, 'agreement': 74, 'customer': 70, 'contract': 70, 'order': 69, 'signed': 69, 'today': 69, 'percent': 68, 'corresponding': 65, 'nokia': 64, 'operation': 63, 'mobile': 63, 'corporation': 59, 'system': 58, 'helsinki': 57, 'industry': 54, 'investment': 54, 'project': 54, 'construction': 52, 'plant': 51, 'loss': 51, 'you': 51, 'hel': 50, 'bank': 49, 'according': 48, 'total': 47, 'building': 47, 'production': 46, 'compared': 46, 'usd': 46, 'network': 46, 'paper': 46, 'russia': 45, 'result': 45, 'last': 43, 'eurm': 43, 'per': 43, 'month': 43, 'unit': 43, 'management': 43, 'area': 42, 'price': 41, 'growth': 40, 'maker': 40, 'financial': 40, 'design': 40, 'stock': 39, 'ceo': 39, 'supply': 37, 'capital': 37, 'leading': 37, 'earlier': 36, 'board': 36, 'acquisition': 36, 'equipment': 36, 'office': 35, 'pct': 35, 'well': 35, 'software': 35, 'cooperation': 35, 'awarded': 35, 'third': 34, 'phone': 34, 'engineering': 34, 'report': 33, 'director': 33, 'second': 33, 'steel': 33, 'country': 33, 'one': 33, 'revenue': 32, 'including': 32, 'would': 31, 'use': 31, 'brand': 31, 'completed': 31, 'world': 30, 'application': 30, 'grew': 30, 'annual': 30, 'device': 30, 'good': 30, 'announced': 29, 'provider': 29, 'development': 29, 'aim': 29, 'make': 29, 'shareholder': 29, 'capacity': 28, 'line': 28, 'oil': 28, 'process': 28, 'omx': 28, 'cost': 28, 'news': 27, 'oy': 27, 'data': 27, 'time': 27, 'right': 27, 'positive': 27, 'plan': 26, 'value': 26, 'yearonyear': 26, 'however': 26, 'information': 26, 'worth': 26, 'subsidiary': 25, 'medium': 25, 'plc': 25, 'europe': 25, 'say': 25, 'ruukki': 25, 'end': 25, 'employee': 24, 'facility': 24, 'expected': 24, 'delivery': 24, 'september': 24, 'earnings': 24, 'manufacturing': 24, 'number': 24, 'exchange': 24, 'baltic': 24, 'store': 24, 'program': 24, 'based': 24, 'operator': 24, 'sector': 24, 'strong': 24, 'offer': 23, 'ltd': 23, 'billion': 23, 'january': 23, 'release': 23, 'part': 23, 'manufacturer': 23, 'future': 23, 'two': 23, 'nine': 23, 'china': 23, 'large': 23, 'basware': 22, 'nordic': 22, 'machine': 22, 'global': 22, 'structure': 22, 'swedish': 22, 'capman': 22, 'largest': 21, 'volume': 21, 'already': 21, 'respectively': 21, 'october': 21, 'distribution': 21, 'developer': 21, 'provides': 21, 'industrial': 21, 'consumer': 21, 'material': 20, 'strategy': 20, 'user': 20, 'developed': 20, 'metal': 20, 'cash': 20, 'pharmaceutical': 20, 'next': 20, 'may': 20, 'improved': 20, 'improve': 19, 'pretax': 19, 'retail': 19, 'st': 19, 'made': 19, 'member': 19, 'february': 19, 'eps': 19, 'fiskars': 19, 'stake': 19, 'july': 19, 'investor': 19, 'estimated': 19, 'continue': 19, 'august': 19, 'inc': 19, 'amount': 19, 'people': 19, 'sport': 19, 'responsible': 19, 'international': 18, 'reported': 18, 'target': 18, 'range': 18, 'petersburg': 18, 'day': 18, 'insurance': 18, 'nordea': 18, 'property': 18, 'aspo': 18, 'sweden': 18, 'three': 18, 'supplier': 18, 'region': 18, 'via': 18, 'partner': 18, 'city': 18, 'fund': 18, 'added': 18, 'start': 18, 'location': 18, 'demand': 17, 'longterm': 17, 'chain': 17, 'handset': 17, 'security': 17, 'tonne': 17, 'kesko': 17, 'sell': 17, 'level': 17, 'position': 17, 'communication': 17, 'food': 17, 'forest': 17, 'trade': 17, 'president': 17, 'e': 17, 'asset': 17, 'includes': 17, 'experience': 17, 'state': 17, 'narrowed': 17, 'saving': 17, 'performance': 17, 'analysis': 17, 'n': 17, 'holding': 16, 'offering': 16, 'purchase': 16, 'december': 16, 'expand': 16, 'june': 16, 'cover': 16, 'generated': 16, 'north': 16, 'provide': 16, 'transaction' ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot the top 20 most frequent words
top_words = word_freq_df.head(20)

plt.figure(figsize=(12, 8))
sns.barplot(x='Frequency', y='Word', data=top_words, palette='viridis')
plt.title('Top 20 Most Frequent Words')
plt.xlabel('Frequency')
plt.ylabel('Words')
plt.show()

# %%
word_freq_df.head()
# Out:
#         Word  Frequency
# 95       eur        581
# 2    company        377
# 23      said        256
# 96        mn        246
# 156  finnish        227

# %%
# Combine all headlines into a single string
all_headlines = ' '.join(df['news_headline'])
all_headlines_2k = ' '.join(df2k['news_headline'])

# Generate the word cloud
wordcloud1 = WordCloud(width=800, 
                       height=400, 
                       background_color='white', 
                       
                       contour_width=3,  # Width of the contour
                       contour_color='blue',  # Color of the contour
                       colormap='viridis'                       
                      ).generate(all_headlines)
wordcloud2 = WordCloud(width=800,
                       height=400,
                       max_font_size=100,
                       min_font_size=10,
                       background_color='white',
                       colormap='plasma'
                      ).generate(all_headlines_2k)
wordcloud3 = WordCloud(width=800,
                       height=400,
                       max_font_size=100,
                       min_font_size=10,
                       background_color='white',                       
                       colormap='inferno'
                      ).generate_from_frequencies(word_frequency)
fig, axes = plt.subplots(3, 1, figsize=(12, 15))
# Display the first word cloud
axes[0].imshow(wordcloud1, interpolation="bilinear")
axes[0].axis("off")
axes[0].set_title('Word Cloud - Full Dataset')
# Display the second word cloud
axes[1].imshow(wordcloud2, interpolation="bilinear")
axes[1].axis("off")
axes[1].set_title('Word Cloud - 2k Dataset')

axes[2].imshow(wordcloud3, interpolation="bilinear")
axes[2].axis("off")
axes[2].set_title('Word Cloud of Word Frequencies')
# plt.subplots_adjust(wspace=0.5)
# plt.axvline(x=10, color='gray', linestyle='--')
plt.show()

# %% [markdown]
# Task #2

# %%
# !pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: spacy in c:\users\usha_\appdata\roaming\python\python311\site-packages (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in d:\anaconda3\lib\site-packages (from spacy) (5.2.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in d:\anaconda3\lib\site-packages (from spacy) (4.65.0)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in d:\anaconda3\lib\site-packages (from spacy) (1.10.12)
# Requirement already satisfied: jinja2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in d:\anaconda3\lib\site-packages (from spacy) (68.2.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from spacy) (1.24.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.2.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from thinc<8.3.0,>=8.2.2->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\usha_\appdata\roaming\python\python311\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from typer<0.10.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from weasel<0.4.0,>=0.1.0->spacy) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from jinja2->spacy) (2.1.3)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\usha_\appdata\roaming\python\python311\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.1.1)

# %%
# !python -m spacy download en_core_web_sm

# %%
# Display POS Tagging for the first two rows... 
# import spacy
import pandas as pd

# Load the spaCy model
# nlp = spacy.load("en_core_web_sm")

# Load the dataset
data = pd.read_csv("all-data.csv",  names=colnames, encoding="windows_1258")
data.style
# Out:
# <style type="text/css">
# </style>
# <table id="T_dced3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dced3_level0_col0" class="col_heading level0 col0" >sentiment</th>
#       <th id="T_dced3_level0_col1" class="col_heading level0 col1" >news_headline</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dced3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dced3_row0_col0" class="data row0 col0" >neutral</td>
#       <td id="T_dced3_row0_col1" class="data row0 col1" >According to Gran , the company has no plans to move all production to Russia , although that is where the company is growing .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dced3_row1_col0" class="data row1 col0" >neutral</td>
#       <td id="T_dced3_row1_col1" class="data row1 col1" >Technopolis plans to develop in stages an area of no less than 100,000 square meters in order to host companies working in computer technologies and telecommunications , the statement said .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dced3_row2_col0" class="data row2 col0" >negative</td>
#       <td id="T_dced3_row2_col1" class="data row2 col1" >The international electronic industry company Elcoteq has laid off tens of employees from its Tallinn facility ; contrary to earlier layoffs the company contracted the ranks of its office workers , the daily Postimees reported .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dced3_row3_col0" class="data row3 col0" >positive</td>
#       <td id="T_dced3_row3_col1" class="data row3 col1" >With the new production plant the company would increase its capacity to meet the expected increase in demand and would improve the use of raw materials and therefore increase the production profitability .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dced3_row4_col0" class="data row4 col0" >positive</td>
#       <td id="T_dced3_row4_col1" class="data row4 col1" >According to the company 's updated strategy for the years 2009-2012 , Basware targets a long-term net sales growth in the range of 20 % -40 % with an operating profit margin of 10 % -20 % of net sales .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dced3_row5_col0" class="data row5 col0" >positive</td>
#       <td id="T_dced3_row5_col1" class="data row5 col1" >FINANCING OF ASPOCOMP 'S GROWTH Aspocomp is aggressively pursuing its growth strategy by increasingly focusing on technologically more demanding HDI printed circuit boards PCBs .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dced3_row6_col0" class="data row6 col0" >positive</td>
#       <td id="T_dced3_row6_col1" class="data row6 col1" >For the last quarter of 2010 , Componenta 's net sales doubled to EUR131m from EUR76m for the same period a year earlier , while it moved to a zero pre-tax profit from a pre-tax loss of EUR7m .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dced3_row7_col0" class="data row7 col0" >positive</td>
#       <td id="T_dced3_row7_col1" class="data row7 col1" >In the third quarter of 2010 , net sales increased by 5.2 % to EUR 205.5 mn , and operating profit by 34.9 % to EUR 23.5 mn .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dced3_row8_col0" class="data row8 col0" >positive</td>
#       <td id="T_dced3_row8_col1" class="data row8 col1" >Operating profit rose to EUR 13.1 mn from EUR 8.7 mn in the corresponding period in 2007 representing 7.7 % of net sales .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dced3_row9_col0" class="data row9 col0" >positive</td>
#       <td id="T_dced3_row9_col1" class="data row9 col1" >Operating profit totalled EUR 21.1 mn , up from EUR 18.6 mn in 2007 , representing 9.7 % of net sales .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dced3_row10_col0" class="data row10 col0" >positive</td>
#       <td id="T_dced3_row10_col1" class="data row10 col1" >TeliaSonera TLSN said the offer is in line with its strategy to increase its ownership in core business holdings and would strengthen Eesti Telekom 's offering to its customers .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dced3_row11_col0" class="data row11 col0" >positive</td>
#       <td id="T_dced3_row11_col1" class="data row11 col1" >STORA ENSO , NORSKE SKOG , M-REAL , UPM-KYMMENE Credit Suisse First Boston ( CFSB ) raised the fair value for shares in four of the largest Nordic forestry groups .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dced3_row12_col0" class="data row12 col0" >positive</td>
#       <td id="T_dced3_row12_col1" class="data row12 col1" >A purchase agreement for 7,200 tons of gasoline with delivery at the Hamina terminal , Finland , was signed with Neste Oil OYj at the average Platts index for this September plus eight US dollars per month .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dced3_row13_col0" class="data row13 col0" >positive</td>
#       <td id="T_dced3_row13_col1" class="data row13 col1" >Finnish Talentum reports its operating profit increased to EUR 20.5 mn in 2005 from EUR 9.3 mn in 2004 , and net sales totaled EUR 103.3 mn , up from EUR 96.4 mn .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dced3_row14_col0" class="data row14 col0" >positive</td>
#       <td id="T_dced3_row14_col1" class="data row14 col1" >Clothing retail chain Sepp+Æl+Æ 's sales increased by 8 % to EUR 155.2 mn , and operating profit rose to EUR 31.1 mn from EUR 17.1 mn in 2004 .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dced3_row15_col0" class="data row15 col0" >positive</td>
#       <td id="T_dced3_row15_col1" class="data row15 col1" >Consolidated net sales increased 16 % to reach EUR74 .8 m , while operating profit amounted to EUR0 .9 m compared to a loss of EUR0 .7 m in the prior year period .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dced3_row16_col0" class="data row16 col0" >positive</td>
#       <td id="T_dced3_row16_col1" class="data row16 col1" >Foundries division reports its sales increased by 9.7 % to EUR 63.1 mn from EUR 57.5 mn in the corresponding period in 2006 , and sales of the Machine Shop division increased by 16.4 % to EUR 41.2 mn from EUR 35.4 mn in the corresponding period in 2006 .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dced3_row17_col0" class="data row17 col0" >positive</td>
#       <td id="T_dced3_row17_col1" class="data row17 col1" >HELSINKI ( AFX ) - Shares closed higher , led by Nokia after it announced plans to team up with Sanyo to manufacture 3G handsets , and by Nokian Tyres after its fourth-quarter earnings report beat analysts ' expectations , dealers said .</td>
#     </tr>
#     <tr>
#       <th id="T_dced3_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dced3_row18_col0" class="data row18 col0" >positive</td>
#       <td id="T_dced3_row18_col1" class="data row18 col1" >Incap Contract Manufacturing Services Pvt Ltd , a subsidiary of Incap Corporation of Finland , plans to double its revenu

# %%
# Display POS tagging for the first 2 rows
for i in range(2):
    doc = nlp(data['News Headline'][i])
    print(f"Sentence {i+1}: {data['News Headline'][i]}")
    for token in doc:
        print(f"{token.text}: {token.pos_}")
    print("\n")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[536], line 3
#       1 # Display POS tagging for the first 2 rows
#       2 for i in range(2):
# ----> 3     doc = nlp(data['News Headline'][i])
#       4     print(f"Sentence {i+1}: {data['News Headline'][i]}")
#       5     for token in doc:
#
# NameError: name 'nlp' is not defined

# %%
# 2. Plot the dependency parser for any two random sentences with at least 10 words

import random
from spacy import displacy

# Filter sentences with at least 10 words
long_sentences = [sent for sent in data['News Headline'] if len(sent.split()) >= 10]

# Select two random sentences
random_sentences = random.sample(long_sentences, 2)

# Plot dependency parser
for sentence in random_sentences:
    doc = nlp(sentence)
    displacy.render(doc, style="dep", jupyter=True)

# %%
# !pip install nltk

# %%
# 3. Plot the Statistical parser for any two random sentences with at least 10 words
# For statistical parsing, we can use the nltk library. 
import nltk
from nltk.parse import CoreNLPParser

# Initialize the CoreNLP parser
parser = CoreNLPParser(url='http://localhost:9000')

# Plot statistical parser for the same random sentences
for sentence in random_sentences:
    parse = next(parser.raw_parse(sentence))
    tree = nltk.Tree.fromstring(str(parse))
    tree.pretty_print()
    tree.draw()

# %%
# Compare the efficiency of each approach
# To compare the efficiency, we can measure the time taken for each approach:

import time

# Measure time for spaCy dependency parsing
start_time = time.time()
for sentence in random_sentences:
    doc = nlp(sentence)
end_time = time.time()
spacy_time = end_time - start_time

# Measure time for NLTK statistical parsing
start_time = time.time()
for sentence in random_sentences:
    parse = next(parser.raw_parse(sentence))
end_time = time.time()
nltk_time = end_time - start_time

print(f"spaCy dependency parsing time: {spacy_time} seconds")
print(f"NLTK statistical parsing time: {nltk_time} seconds")
